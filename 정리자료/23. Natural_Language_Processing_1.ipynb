# %% [markdown]
# # Natural Language Processing1

# %% [markdown]
# 텍스트에서 의미있는 정보를 분석, 추출하고 이해하는 일련의 기술집합이다.

# %% [markdown]
# ## Tokenize

# %%
from nltk.corpus import gutenberg

# %%
gutenberg.fileids() #nltk의 corpus에 있는 파일들
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
corpus = gutenberg.open('austen-emma.txt').read() # corpus의 파일을 읽어온다.

# %%
from nltk import regexp_tokenize, Text 
# regular expression을 이용해서 해당하는 패턴을 만족하는 text찾을 것

# %%
pattern = r"([a-zA-Z0-9]+)+" #정규식으로 해당 패턴을 만들어 준다.
# 영어, 숫자 조합으로 1개 이상의 글자를 지니는 그룹을 1개 이상 가지는 패턴

# %%
tokens = regexp_tokenize(corpus, pattern) #해당 corpus를 pattern에 맞게 tokenize해줌

# %%
len(tokens)
# Out:
# 161980

# %%
en = Text(tokens)

# %%
type(en) # token들을 Text 객체로 만들어줌.
# Out:
# nltk.text.Text

# %%
from konlpy.corpus import kolaw

# %%
corpus = kolaw.open("constitution.txt").read() # kolaw에 있는 corpus를 들고온다.

# %%
from konlpy.tag import Kkma # 꼬꼬마 형태소 분석기를 들고옴.

# %%
kkma = Kkma() # 꼬고마 형태소 객체 생성

# %%
tokens = kkma.morphs(corpus) # 꼬꼬마 형태소 분석기로 corpus를 토큰화해줌.

# %%
tokens[:5]
# Out:
# ['대한민국', '헌법', '유구', '하', 'ㄴ']

# %%
ko = Text(tokens) # 한국어 토큰들에 대해 Text 객체를 만들어줌

# %% [markdown]
# ## collocation :
# #### 2개 이상의 단어가 함께 의미를 전달하기 위해 사용되는 단어들의 덩어리

# %% [markdown]
# ### 임의로 자신이 만든 rule에 대해 parsing tree 구축

# %%
sentence = "The little yellow dog barked at the Persian cat"

# %%
tokens = sentence.split() # 어절 단위로 (Whitespace 단위로) 토큰화해준다.

# %%
import nltk

# %%
nltk.__version__
# Out:
# '3.2.4'

# %%
enTags = nltk.pos_tag(tokens) # 토큰에 대해서 품사 tagging해준다.
# 튜플 리스트로 리턴해준다.

# %%
enTags
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Persian', 'JJ'),
#  ('cat', 'NN')]

# %%
sentence = "내 친구는 잠을 많이 잔다."

# %%
koTags = kkma.pos(sentence) # 꼬꼬마 형태소 분석기로 토큰화 및 품사 태깅 해준다.

# %%
koTags
# Out:
# [('내', 'NP'),
#  ('친구', 'NNG'),
#  ('는', 'JX'),
#  ('잠', 'NNG'),
#  ('을', 'JKO'),
#  ('많이', 'MAG'),
#  ('자', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF')]

# %%
enParser = nltk.RegexpParser("NP: {<DT>?<JJ>*<NN.*>*}") 
# 정규식에 맞게 품사 태깅 해줄 수 있게 해줌.
# 관사<DT>가 있을수도 있고, 형용사<JJ> 0개 이상, 
# ( <NN> 뒤에 무엇이 0개이상 붙는 것 )이 0개 이상 인것..

# %%
tree = enParser.parse(enTags) 
#해당 Parser의 grammar에 따라서 parse tree 생성해줌.

# %%
tree.draw() # 해당 parse tree를 그려줌. 새창으로 띄워준다.

# %%
tree.pprint() # 이렇게 출력해주기도 한다.
# Out:
# (S
#   (NP The/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT Persian/JJ cat/NN))

# %%
koParser = nltk.RegexpParser("""
NP: {<N.*>*<N.*>?}
OP: {<N.*>*<JKO>*}
VP: {<M.*>*<V.*>*<E.*>*}
""") # 해당 정규식 grammar에 맞게 parser를 만들어준다.
#명사구(NP)는 (N으로 시작하고, N뒤에 0개 이상이 붙는것)이 0개 이상이고, 또하나가 더 올 수 있는 것 
#동사구(VP)는 (M으로 시작하는 것이 0개 이상, V로 시작하는것이 0개이상, E로 시작하는 것이 0개 이상)

# %%
tree = koParser.parse(koTags) # 위의 parser에 맞게 parse tree 만들어줌

# %%
tree.draw() # parse tree를 만들어준다.

# %%
tree.pprint()
# Out:
# (S
#   (OP (NP 내/NP 친구/NNG))
#   는/JX
#   (OP (NP 잠/NNG) 을/JKO)
#   (VP 많이/MAG 자/VV ㄴ다/EFN)
#   ./SF)

# %%
for subtree in tree.subtrees(): #서브트리 for문 돌린다.
    if subtree.label() == "VP": # 만약 tag가 VP일때
        print(subtree,type(subtree)) #subtree와 타입을 출력
        print(list(subtree)) #subtree의 토큰 된것들 리스트화 해서 출력
        print(" ".join(e[0] for e in list(subtree))) #토큰화된것들 묶어서 출력
# Out:
# (VP 많이/MAG 자/VV ㄴ다/EFN) <class 'nltk.tree.Tree'>
# [('많이', 'MAG'), ('자', 'VV'), ('ㄴ다', 'EFN')]
# 많이 자 ㄴ다

# %% [markdown]
# ### collocation

# %%
en.collocations() #단어쌍이 많은 것들 출력해준다. (연어)
# Out:
# Mrs Weston; Frank Churchill; Miss Woodhouse; Mrs Elton; Miss Bates;
# Jane Fairfax; Miss Fairfax; every thing; young man; every body; great
# deal; Mrs Goddard; dare say; Maple Grove; John Knightley; Miss Taylor;
# Miss Smith; Robert Martin; Colonel Campbell; Box Hill

# %%
ko.collocations(window_size=3) #단어의 위치 기반으로 단어쌍이 많은 것들 출력해준다.
#연속된 단어 중에 window 크기를 3으로 해서 많이 나오는 단어쌍을 출력해준다.
# Out:
# 정치적 중립성; 재판소 재판관; 대법원장 대법관; 대통령 국무총리; 그러하 아니하

# %% [markdown]
# PMI : 2개의 독립적인 이산 확률을 통해서 2가지의 관계성을 확인할 수 있도록 해준다.
#
# <br>감성분석, opinion mining을 하는데 쓰인다.

# %% [markdown]
# ### Bigram

# %% [markdown]
# 확률론적 언어 모형(Probabilistic Language Model)은  m 개의 단어  $w1,w2,…,wm$  열(word sequence)이 주어졌을 때 문장으로써 성립될 확률  $P(w1,w2,…,wm)$  을 출력함으로써 이 단어 열이 실제로 현실에서 사용될 수 있는 문장(sentence)인지를 판별하는 모형이다.

# %% [markdown]
# 만약 단어의 활용이 바로 전 단어에만 의존한다면 단어 열의 확률은 다음과 같다. 이러한 모형을 Bigram 모형 또는 마코프 모형(Markov Model)이라고 한다.
#
# $$
# P(w1,w2,…,wm)=P(w1) ∏ i=2mP(wi|wi−1)
# $$

# %% [markdown]
# [확률론적 언어 모델 설명 링크](https://datascienceschool.net/view-notebook/a0c848e1e2d343d685e6077c35c4203b/)

# %%
from nltk import collocations
#연어를 활용해서 통계적으로 관련성이 있는 것들을 알려고 한다.

# %%
measure = collocations.BigramAssocMeasures()
# bigram 객체 생성

# %%
taggedWords = kkma.pos(corpus) # corpus에 대해서 tokenizing 및 tagging해준다.

# %%
taggedWords
# Out:
# [('대한민국', 'NNG'),
#  ('헌법', 'NNG'),
#  ('유구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('전통', 'NNG'),
#  ('에', 'JKM'),
#  ('빛나', 'VV'),
#  ('는', 'ETD'),
#  ('우리', 'NNM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('3', 'NR'),
#  ('·', 'SP'),
#  ('1', 'NR'),
#  ('운동', 'NNG'),
#  ('으로', 'JKM'),
#  ('건립', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('임시', 'NNG'),
#  ('정부', 'NNG'),
#  ('의', 'JKG'),
#  ('법통', 'NNG'),
#  ('과', 'JC'),
#  ('불의', 'NNG'),
#  ('에', 'JKM'),
#  ('항거', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('4', 'NR'),
#  ('·', 'SP'),
#  ('19', 'NR'),
#  ('민주', 'NNG'),
#  ('이념', 'NNG'),
#  ('을', 'JKO'),
#  ('계승', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('조국', 'NNG'),
#  ('의', 'JKG'),
#  ('민주', 'NNG'),
#  ('개혁', 'NNG'),
#  ('과', 'JKM'),
#  ('평화적', 'NNG'),
#  ('통일', 'NNG'),
#  ('의', 'JKG'),
#  ('사명', 'NNG'),
#  ('에', 'JKM'),
#  ('입각', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'ECS'),
#  ('정의', 'NNG'),
#  ('·', 'SP'),
#  ('인도', 'NNG'),
#  ('와', 'JC'),
#  ('동포애', 'NNG'),
#  ('로써', 'JKM'),
#  ('민족', 'NNG'),
#  ('의', 'JKG'),
#  ('단결', 'NNG'),
#  ('을', 'JKO'),
#  ('공고히', 'MAG'),
#  ('하', 'VV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('모든', 'MDT'),
#  ('사회적', 'NNG'),
#  ('폐습', 'NNG'),
#  ('과', 'JC'),
#  ('불의', 'NNG'),
#  ('를', 'JKO'),
#  ('타파', 'NNG'),
#  ('하', 'XSV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('자율', 'NNG'),
#  ('과', 'JC'),
#  ('조화', 'NNG'),
#  ('를', 'JKO'),
#  ('바탕', 'NNG'),
#  ('으로', 'JKM'),
#  ('자유', 'NNG'),
#  ('민주적', 'NNG'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('를', 'JKO'),
#  ('더욱', 'MAG'),
#  ('확고히', 'MAG'),
#  ('하여', 'MAG'),
#  ('정치', 'NNG'),
#  ('·', 'SP'),
#  ('경제', 'NNG'),
#  ('·', 'SP'),
#  ('사회', 'NNG'),
#  ('·', 'SP'),
#  ('문화', 'NNG'),
#  ('의', 'JKG'),
#  ('모든', 'MDT'),
#  ('영역', 'NNG'),
#  ('에', 'JKM'),
#  ('있', 'VV'),
#  ('어서', 'ECD'),
#  ('각인', 'NNG'),
#  ('의', 'JKG'),
#  ('기회', 'NNG'),
#  ('를', 'JKO'),
#  ('균등', 'NNG'),
#  ('히', 'NNG'),
#  ('하', 'VV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('능력', 'NNG'),
#  ('을', 'JKO'),
#  ('최고', 'NNG'),
#  ('도로', 'NNG'),
#  ('발휘', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'ECD'),
#  ('하', 'VV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('자유', 'NNG'),
#  ('와', 'JC'),
#  ('권리', 'NNG'),
#  ('에', 'JKM'),
#  ('따르', 'VV'),
#  ('는', 'ETD'),
#  ('책임', 'NNG'),
#  ('과', 'JC'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('완수', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'ECD'),
#  ('하여', 'MAG'),
#  (',', 'SP'),
#  ('안', 'NNG'),
#  ('으로', 'JKM'),
#  ('는', 'JX'),
#  ('국민', 'NNG'),
#  ('생활', 'NNG'),
#  ('의', 'JKG'),
#  ('균등', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('향상', 'NNG'),
#  ('을', 'JKO'),
#  ('기하', 'VV'),
#  ('고', 'ECE'),
#  ('밖', 'NNG'),
#  ('으로', 'JKM'),
#  ('는', 'JX'),
#  ('항구적', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETD'),
#  ('세계', 'NNG'),
#  ('평화', 'NNG'),
#  ('와', 'JC'),
#  ('인류', 'NNG'),
#  ('공영', 'NNG'),
#  ('에', 'JKM'),
#  ('이바지', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅁ', 'ETN'),
#  ('으로써', 'JKM'),
#  ('우리', 'NP'),
#  ('들', 'XSN'),
#  ('과', 'JKO'),
#  ('우리', 'NP'),
#  ('들', 'XSN'),
#  ('의', 'JKG'),
#  ('자손', 'NNG'),
#  ('의', 'JKG'),
#  ('안전', 'NNG'),
#  ('과', 'JC'),
#  ('자유', 'NNG'),
#  ('와', 'JC'),
#  ('행복', 'NNG'),
#  ('을', 'JKO'),
#  ('영원히', 'MAG'),
#  ('확보', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('다짐', 'NNG'),
#  ('하', 'XSV'),
#  ('면서', 'ECE'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('7', 'NR'),
#  ('월', 'NNM'),
#  ('12', 'NR'),
#  ('일', 'NNM'),
#  ('에', 'JKM'),
#  ('제정', 'NNG'),
#  ('되', 'XSV'),
#  ('고', 'ECE'),
#  ('8', 'NR'),
#  ('차', 'NNM'),
#  ('에', 'JKM'),
#  ('걸치', 'VV'),
#  ('어', 'ECS'),
#  ('개정', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('헌법', 'NNG'),
#  ('을', 'JKO'),
#  ('이제', 'NNG'),
#  ('국회', 'NNG'),
#  ('의', 'JKG'),
#  ('의결', 'NNG'),
#  ('을', 'JKO'),
#  ('거치', 'VV'),
#  ('어', 'ECS'),
#  ('국민', 'NNG'),
#  ('투표', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('개정', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('1', 'NR'),
#  ('장', 'NNM'),
#  ('총', 'MDT'),
#  ('강', 'NNG'),
#  ('제', 'NNG'),
#  ('1', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('주권', 'NNG'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('에게', 'JKM'),
#  ('있', 'VV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('모든', 'MDT'),
#  ('권력', 'NNG'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('으로', 'JKM'),
#  ('부터', 'JX'),
#  ('나오', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('2', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국민', 'NNG'),
#  ('이', 'JKC'),
#  ('되', 'VV'),
#  ('는', 'ETD'),
#  ('요건', 'NNG'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('로', 'JKM'),
#  ('정하', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETD'),
#  ('바', 'NNB'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('재외', 'NNG'),
#  ('국민', 'NNG'),
#  ('을', 'JKO'),
#  ('보호', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('질', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('3', 'NR'),
#  ('조', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('영토', 'NNG'),
#  ('는', 'JX'),
#  ('한반도', 'NNG'),
#  ('와', 'JC'),
#  ('그', 'MDT'),
#  ('부속', 'NNG'),
#  ('도', 'JX'),
#  ('서로', 'MAG'),
#  ('하', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('4', 'NR'),
#  ('조', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('통일', 'NNG'),
#  ('을', 'JKO'),
#  ('지향', 'NNG'),
#  ('하', 'XSV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('자유', 'NNG'),
#  ('민주적', 'NNG'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('에', 'JKM'),
#  ('입각', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('평화적', 'NNG'),
#  ('통일', 'NNG'),
#  ('정책', 'NNG'),
#  ('을', 'JKO'),
#  ('수립', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('이르', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('추진', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('5', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('국제', 'NNG'),
#  ('평화', 'NNG'),
#  ('의', 'JKG'),
#  ('유지', 'NNG'),
#  ('에', 'JKM'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('침략', 'NNG'),
#  ('적', 'XSN'),
#  ('전쟁', 'NNG'),
#  ('을', 'JKO'),
#  ('부인', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('국', 'NNG'),
#  ('군은', 'NNG'),
#  ('국가', 'NNG'),
#  ('의', 'JKG'),
#  ('안전', 'NNG'),
#  ('보장', 'NNG'),
#  ('과', 'JC'),
#  ('국토', 'NNG'),
#  ('방위', 'NNG'),
#  ('의', 'JKG'),
#  ('신성', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('수행', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅁ', 'ETN'),
#  ('을', 'JKO'),
#  ('사명', 'NNG'),
#  ('으로', 'JKM'),
#  ('하', 'VV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('그', 'MDT'),
#  ('정치적', 'NNG'),
#  ('중립성', 'NNG'),
#  ('은', 'JX'),
#  ('준수', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('6', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('헌법', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('체결', 'NNG'),
#  ('·', 'SP'),
#  ('공포', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('조약', 'NNG'),
#  ('과', 'JKM'),
#  ('일반적', 'NNG'),
#  ('으로', 'JKM'),
#  ('승인', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('국제', 'NNG'),
#  ('법규', 'NNG'),
#  ('는', 'JX'),
#  ('국내', 'NNG'),
#  ('법과', 'NNG'),
#  ('같', 'VA'),
#  ('은', 'ETD'),
#  ('효력', 'NNG'),
#  ('을', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('외국인', 'NNG'),
#  ('은', 'JX'),
#  ('국제법', 'NNG'),
#  ('과', 'JC'),
#  ('조약', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETD'),
#  ('바', 'NNB'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('그', 'MDT'),
#  ('지위', 'NNG'),
#  ('가', 'JKS'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('7', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('공무원', 'NNG'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('전체', 'NNG'),
#  ('에', 'JKM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('봉사자', 'NNG'),
#  ('이', 'VCP'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('국민', 'NNG'),
#  ('에', 'JKM'),
#  ('대하', 'VV'),
#  ('여', 'ECS'),
#  ('책임', 'NNG'),
#  ('을', 'JKO'),
#  ('질', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('공무원', 'NNG'),
#  ('의', 'JKG'),
#  ('신분', 'NNG'),
#  ('과', 'JKM'),
#  ('정치적', 'NNG'),
#  ('중립성', 'NNG'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETD'),
#  ('바', 'NNB'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('8', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('정당', 'NNG'),
#  ('의', 'JKG'),
#  ('설립', 'NNG'),
#  ('은', 'JX'),
#  ('자유', 'NNG'),
#  ('이', 'VCP'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('복수', 'NNG'),
#  ('정당제', 'NNG'),
#  ('는', 'JX'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('정당', 'NNG'),
#  ('은', 'JX'),
#  ('그', 'MDT'),
#  ('목적', 'NNG'),
#  ('·', 'SP'),
#  ('조직', 'NNG'),
#  ('과', 'JKM'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('민주적', 'NNG'),
#  ('이', 'VCP'),
#  ('어야', 'ECD'),
#  ('하', 'VV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('국민', 'NNG'),
#  ('의', 'JKG'),
#  ('정치적', 'NNG'),
#  ('의사', 'NNG'),
#  ('형성', 'NNG'),
#  ('에', 'JKM'),
#  ('참여', 'NNG'),
#  ('하', 'XSV'),
#  ('는데', 'ECD'),
#  ('필요', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('조직', 'NNG'),
#  ('을', 'JKO'),
#  ('가지', 'VV'),
#  ('어야', 'ECD'),
#  ('하', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('정당', 'NNG'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETD'),
#  ('바', 'NNB'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('국가', 'NNG'),
#  ('의', 'JKG'),
#  ('보호', 'NNG'),
#  ('를', 'JKO'),
#  ('받', 'VV'),
#  ('으며', 'ECE'),
#  (',', 'SP'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETD'),
#  ('바', 'NNB'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('정당', 'NNG'),
#  ('운영', 'NNG'),
#  ('에', 'JKM'),
#  ('필요', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('자금', 'NNG'),
#  ('을', 'JKO'),
#  ('보조', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('④', 'SW'),
#  ('정당', 'NNG'),
#  ('의', 'JKG'),
#  ('목적', 'NNG'),
#  ('이나', 'JC'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('민주적', 'NNG'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('에', 'JKM'),
#  ('위배', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('때', 'NNG'),
#  ('에', 'JKM'),
#  ('는', 'JX'),
#  ('정부', 'NNG'),
#  ('는', 'JX'),
#  ('헌법', 'NNG'),
#  ('재판소', 'NNG'),
#  ('에', 'JKM'),
#  ('그', 'MDT'),
#  ('해산', 'NNG'),
#  ('을', 'JKO'),
#  ('제소', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('정당', 'NNG'),
#  ('은', 'JX'),
#  ('헌법', 'NNG'),
#  ('재판소', 'NNG'),
#  ('의', 'JKG'),
#  ('심판', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('해산', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('9', 'NR'),
#  ('조', 'NNM'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('전통문화', 'NNG'),
#  ('의', 'JKG'),
#  ('계승', 'NNG'),
#  ('·', 'SP'),
#  ('발전', 'NNG'),
#  ('과', 'JC'),
#  ('민족', 'NNG'),
#  ('문화', 'NNG'),
#  ('의', 'JKG'),
#  ('창달', 'NNG'),
#  ('에', 'JKM'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('여야', 'ECD'),
#  ('하', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('2', 'NR'),
#  ('장', 'NNG'),
#  ('국민', 'NNG'),
#  ('의', 'JKG'),
#  ('권리', 'NNG'),
#  ('와', 'JC'),
#  ('의무', 'NNG'),
#  ('제', 'NNG'),
#  ('10', 'NR'),
#  ('조', 'NNM'),
#  ('모든', 'MDT'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('인간', 'NNG'),
#  ('으로서', 'JKM'),
#  ('의', 'JKG'),
#  ('존엄', 'NNG'),
#  ('과', 'JC'),
#  ('가치', 'NNG'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('행복', 'NNG'),
#  ('을', 'JKO'),
#  ('추구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('권리', 'NNG'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('개인', 'NNG'),
#  ('이', 'JKS'),
#  ('가지', 'VV'),
#  ('는', 'ETD'),
#  ('불가침', 'NNG'),
#  ('의', 'JKG'),
#  ('기본적', 'NNG'),
#  ('인권', 'NNG'),
#  ('을', 'JKO'),
#  ('확인', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('이르', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('보장', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('질', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('11', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('모든', 'NNP'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('법', 'NNG'),
#  ('앞', 'NNG'),
#  ('에', 'JKM'),
#  ('평등', 'NNG'),
#  ('하', 'XSA'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('누구', 'NP'),
#  ('든지', 'JX'),
#  ('성별', 'NNG'),
#  ('·', 'SP'),
#  ('종교', 'NNG'),
#  ('또는', 'MAG'),
#  ('사회적', 'NNG'),
#  ('신분', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('정치적', 'NNG'),
#  ('·', 'SP'),
#  ('경제적', 'NNG'),
#  ('·', 'SP'),
#  ('사회적', 'NNG'),
#  ('·', 'SP'),
#  ('문화적', 'NNG'),
#  ('생활', 'NNG'),
#  ('의', 'JKG'),
#  ('모든', 'MDT'),
#  ('영역', 'NNG'),
#  ('에', 'JKM'),
#  ('있', 'VV'),
#  ('어서', 'ECD'),
#  ('차별', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('사회적', 'NNG'),
#  ('특수', 'NNG'),
#  ('계급', 'NNG'),
#  ('의', 'JKG'),
#  ('제도', 'NNG'),
#  ('는', 'JX'),
#  ('인정', 'NNG'),
#  ('되', 'XSV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('어떠하', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('형태', 'NNG'),
#  ('로', 'JKM'),
#  ('도', 'JX'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('창설', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETD'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('훈장', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('영전', 'NNG'),
#  ('은', 'JX'),
#  ('이르', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('받', 'VA'),
#  ('은', 'ETD'),
#  ('자', 'NNG'),
#  ('에게', 'JKM'),
#  ('만', 'JX'),
#  ('효력', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('어떠하', 'VA'),
#  ('ㄴ', 'ETD'),
#  ('특권', 'NNG'),
#  ('도', 'JX'),
#  ('이에', 'MAG'),
#  ('따르', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('12', 'NR'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('모든', 'NNP'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('신체', 'NNG'),
#  ('의', 'JKG'),
#  ('자유', 'NNG'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('누구', 'NP'),
#  ('든지', 'JX'),
#  ('법률', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('고는', 'ECE'),
#  ('체포', 'NNG'),
#  ('·', 'SP'),
#  ('구속', 'NNG'),
#  ('·', 'SP'),
#  ('압수', 'NNG'),
#  ('·', 'SP'),
#  ('수색', 'NNG'),
#  ('또는', 'MAG'),
#  ('심문', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('법률', 'NNG'),
#  ('과', 'JKM'),
#  ('적법', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('절차', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('고는', 'ECE'),
#  ('처벌', 'NNG'),
#  ('·', 'SP'),
#  ('보안', 'NNG'),
#  ('처분', 'NNG'),
#  ('또는', 'MAG'),
#  ('강제', 'NNG'),
#  ('노역', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('모든', 'NNP'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('고문', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('형', 'NNG'),
#  ('사상', 'NNG'),
#  ('자기', 'NP'),
#  ('에게', 'JKM'),
#  ('불리', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('진술', 'NNG'),
#  ('을', 'JKO'),
#  ('강요', 'NNG'),
#  ('당하', 'XSV'),
#  ('지', 'ECD'),
#  ('아니하', 'VXV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('체포', 'NNG'),
#  ('·', 'SP'),
#  ('구속', 'NNG'),
#  ('·', 'SP'),
#  ('압수', 'NNG'),
#  ('또는', 'MAG'),
#  ('수색', 'NNG'),
#  ('을', 'JKO'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETD'),
#  ('때', 'NNG'),
#  ('에', 'JKM'),
#  ('는', 'JX'),
#  ('적법', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('절차', 'NNG'),
#  ('에', 'JKM'),
#  ('따르', 'VV'),
#  ('아', 'ECS'),
#  ('검사', 'NNG'),
#  ('의', 'JKG'),
#  ('신청', 'NNG'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('여', 'ECS'),
#  ('법관', 'NNG'),
#  ('이', 'JKS'),
#  ('발부', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('영장', 'NNG'),
#  ('을', 'JKO'),
#  ('제시', 'NNG'),
#  ('하', 'XSV'),
#  ('여야', 'ECD'),
#  ('하', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF'),
#  ('다만', 'MAG'),
#  (',', 'SP'),
#  ('현행', 'NNG'),
#  ('범인', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETD'),
#  ('경우', 'NNG'),
#  ('와', 'JC'),
#  ('장기', 'NNG'),
#  ('3', 'NR'),
#  ('년', 'NNM'),
#  ('이상', 'NNG'),
#  ('의', 'JKG'),
#  ('형', 'NNG'),
#  ('에', 'JKM'),
#  ('해당', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETD'),
#  ('죄', 'NNG'),
#  ('를', 'JKO'),
#  ('범하', 'VV'),
#  ('고', 'ECE'),
#  ('도피', 'NNG'),
#  ('또는', 'MAG'),
#  ('증거', 'NNG'),
#  ('인멸', 'NNG'),
#  ('의', 'JKG'),
#  ('염려', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('을', 'ETD'),
#  ('때', 'NNG'),
#  ('에', 'JKM'),
#  ('는', 'JX'),
#  ...]

# %%
finder = collocations.BigramCollocationFinder.from_words(taggedWords)
#이미 형태소 분석이 되어 있으므로 단어에서 Bigram을 갖고 온다.

# %%
for row in finder.nbest(measure.pmi, 5):
    print(row)
#pmi 척도로 상위 5개의 ,bigram 쌍을 출력할 것이다.
# Out:
# (('가부', 'NNG'), ('동수', 'NNG'))
# (('강제', 'NNG'), ('노역', 'NNG'))
# (('경자', 'NNG'), ('유전', 'NNG'))
# (('고', 'ECS'), ('채취', 'NNG'))
# (('공무', 'NNG'), ('담임', 'NNG'))

# %%
tags = [t for (w, t) in taggedWords] # tag들을 list로 묶어준다.

# %%
tags
# Out:
# ['NNG',
#  'NNG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNM',
#  'VV',
#  'ETD',
#  'NNG',
#  'JX',
#  'NR',
#  'SP',
#  'NR',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NR',
#  'SP',
#  'NR',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'MAG',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'MAG',
#  'MAG',
#  'MAG',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'JKG',
#  'MDT',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'MAG',
#  'SP',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'VCP',
#  'ETD',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETN',
#  'JKM',
#  'NP',
#  'XSN',
#  'JKO',
#  'NP',
#  'XSN',
#  'JKG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'MAG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NR',
#  'NNM',
#  'NR',
#  'NNM',
#  'NR',
#  'NNM',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NR',
#  'NNM',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'MDT',
#  'NNG',
#  'NNG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'VCP',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'JX',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKC',
#  'VV',
#  'ETD',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JC',
#  'MDT',
#  'NNG',
#  'JX',
#  'MAG',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'VV',
#  'ETD',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NNG',
#  'XSN',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETN',
#  'JKO',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'MDT',
#  'NNG',
#  'JKS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNG',
#  'VCP',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'VCP',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'MDT',
#  'NNG',
#  'SP',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKS',
#  'NNG',
#  'VCP',
#  'ECD',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECD',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKS',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'MDT',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKG',
#  'NNG',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'NR',
#  'NNM',
#  'MDT',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'VV',
#  'ETD',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSA',
#  'EFN',
#  'SF',
#  'NP',
#  'JX',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'NNG',
#  'JKG',
#  'MDT',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NP',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VA',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNB',
#  'JKG',
#  'NNG',
#  'JX',
#  'VV',
#  'ETD',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ECE',
#  'SP',
#  'VA',
#  'ETD',
#  'NNG',
#  'JX',
#  'MAG',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'NNG',
#  'SP',
#  'NNG',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'NP',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKS',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'MAG',
#  'SP',
#  'NNG',
#  'NNG',
#  'VCP',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  ...]

# %%
words = [w for (w,t) in taggedWords] # 단어들을 list로 묶어준다.

# %%
words
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '하',
#  'ㄴ',
#  '역사',
#  '와',
#  '전통',
#  '에',
#  '빛나',
#  '는',
#  '우리',
#  '대하',
#  'ㄴ',
#  '국민',
#  '은',
#  '3',
#  '·',
#  '1',
#  '운동',
#  '으로',
#  '건립',
#  '되',
#  'ㄴ',
#  '대한민국',
#  '임시',
#  '정부',
#  '의',
#  '법통',
#  '과',
#  '불의',
#  '에',
#  '항거',
#  '하',
#  'ㄴ',
#  '4',
#  '·',
#  '19',
#  '민주',
#  '이념',
#  '을',
#  '계승',
#  '하',
#  '고',
#  ',',
#  '조국',
#  '의',
#  '민주',
#  '개혁',
#  '과',
#  '평화적',
#  '통일',
#  '의',
#  '사명',
#  '에',
#  '입각',
#  '하',
#  '여',
#  '정의',
#  '·',
#  '인도',
#  '와',
#  '동포애',
#  '로써',
#  '민족',
#  '의',
#  '단결',
#  '을',
#  '공고히',
#  '하',
#  '고',
#  ',',
#  '모든',
#  '사회적',
#  '폐습',
#  '과',
#  '불의',
#  '를',
#  '타파',
#  '하',
#  '며',
#  ',',
#  '자율',
#  '과',
#  '조화',
#  '를',
#  '바탕',
#  '으로',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '를',
#  '더욱',
#  '확고히',
#  '하여',
#  '정치',
#  '·',
#  '경제',
#  '·',
#  '사회',
#  '·',
#  '문화',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '각인',
#  '의',
#  '기회',
#  '를',
#  '균등',
#  '히',
#  '하',
#  '고',
#  ',',
#  '능력',
#  '을',
#  '최고',
#  '도로',
#  '발휘',
#  '하',
#  '게',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '와',
#  '권리',
#  '에',
#  '따르',
#  '는',
#  '책임',
#  '과',
#  '의무',
#  '를',
#  '완수',
#  '하',
#  '게',
#  '하여',
#  ',',
#  '안',
#  '으로',
#  '는',
#  '국민',
#  '생활',
#  '의',
#  '균등',
#  '하',
#  'ㄴ',
#  '향상',
#  '을',
#  '기하',
#  '고',
#  '밖',
#  '으로',
#  '는',
#  '항구적',
#  '이',
#  'ㄴ',
#  '세계',
#  '평화',
#  '와',
#  '인류',
#  '공영',
#  '에',
#  '이바지',
#  '하',
#  'ㅁ',
#  '으로써',
#  '우리',
#  '들',
#  '과',
#  '우리',
#  '들',
#  '의',
#  '자손',
#  '의',
#  '안전',
#  '과',
#  '자유',
#  '와',
#  '행복',
#  '을',
#  '영원히',
#  '확보',
#  '하',
#  'ㄹ',
#  '것',
#  '을',
#  '다짐',
#  '하',
#  '면서',
#  '1948',
#  '년',
#  '7',
#  '월',
#  '12',
#  '일',
#  '에',
#  '제정',
#  '되',
#  '고',
#  '8',
#  '차',
#  '에',
#  '걸치',
#  '어',
#  '개정',
#  '되',
#  'ㄴ',
#  '헌법',
#  '을',
#  '이제',
#  '국회',
#  '의',
#  '의결',
#  '을',
#  '거치',
#  '어',
#  '국민',
#  '투표',
#  '에',
#  '의하',
#  '여',
#  '개정',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '1',
#  '장',
#  '총',
#  '강',
#  '제',
#  '1',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '민주',
#  '공화국',
#  '이',
#  '다',
#  '.',
#  '②',
#  '대한민국',
#  '의',
#  '주권',
#  '은',
#  '국민',
#  '에게',
#  '있',
#  '고',
#  ',',
#  '모든',
#  '권력',
#  '은',
#  '국민',
#  '으로',
#  '부터',
#  '나오',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '조',
#  '①',
#  '대한민국',
#  '의',
#  '국민',
#  '이',
#  '되',
#  '는',
#  '요건',
#  '은',
#  '법률',
#  '로',
#  '정하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '재외',
#  '국민',
#  '을',
#  '보호',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '3',
#  '조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도',
#  '서로',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '4',
#  '조',
#  '대한민국',
#  '은',
#  '통일',
#  '을',
#  '지향',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '입각',
#  '하',
#  'ㄴ',
#  '평화적',
#  '통일',
#  '정책',
#  '을',
#  '수립',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '추진',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '5',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '국제',
#  '평화',
#  '의',
#  '유지',
#  '에',
#  '노력',
#  '하',
#  '고',
#  '침략',
#  '적',
#  '전쟁',
#  '을',
#  '부인',
#  '하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국',
#  '군은',
#  '국가',
#  '의',
#  '안전',
#  '보장',
#  '과',
#  '국토',
#  '방위',
#  '의',
#  '신성',
#  '하',
#  'ㄴ',
#  '의무',
#  '를',
#  '수행',
#  '하',
#  'ㅁ',
#  '을',
#  '사명',
#  '으로',
#  '하',
#  '며',
#  ',',
#  '그',
#  '정치적',
#  '중립성',
#  '은',
#  '준수',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '6',
#  '조',
#  '①',
#  '헌법',
#  '에',
#  '의하',
#  '여',
#  '체결',
#  '·',
#  '공포',
#  '되',
#  'ㄴ',
#  '조약',
#  '과',
#  '일반적',
#  '으로',
#  '승인',
#  '되',
#  'ㄴ',
#  '국제',
#  '법규',
#  '는',
#  '국내',
#  '법과',
#  '같',
#  '은',
#  '효력',
#  '을',
#  '가지',
#  'ㄴ다',
#  '.',
#  '②',
#  '외국인',
#  '은',
#  '국제법',
#  '과',
#  '조약',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '그',
#  '지위',
#  '가',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '7',
#  '조',
#  '①',
#  '공무원',
#  '은',
#  '국민',
#  '전체',
#  '에',
#  '대하',
#  'ㄴ',
#  '봉사자',
#  '이',
#  '며',
#  ',',
#  '국민',
#  '에',
#  '대하',
#  '여',
#  '책임',
#  '을',
#  '질',
#  'ㄴ다',
#  '.',
#  '②',
#  '공무원',
#  '의',
#  '신분',
#  '과',
#  '정치적',
#  '중립성',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '8',
#  '조',
#  '①',
#  '정당',
#  '의',
#  '설립',
#  '은',
#  '자유',
#  '이',
#  '며',
#  ',',
#  '복수',
#  '정당제',
#  '는',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '②',
#  '정당',
#  '은',
#  '그',
#  '목적',
#  '·',
#  '조직',
#  '과',
#  '활동',
#  '이',
#  '민주적',
#  '이',
#  '어야',
#  '하',
#  '며',
#  ',',
#  '국민',
#  '의',
#  '정치적',
#  '의사',
#  '형성',
#  '에',
#  '참여',
#  '하',
#  '는데',
#  '필요',
#  '하',
#  'ㄴ',
#  '조직',
#  '을',
#  '가지',
#  '어야',
#  '하',
#  'ㄴ다',
#  '.',
#  '③',
#  '정당',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '국가',
#  '의',
#  '보호',
#  '를',
#  '받',
#  '으며',
#  ',',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '정당',
#  '운영',
#  '에',
#  '필요',
#  '하',
#  'ㄴ',
#  '자금',
#  '을',
#  '보조',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '다',
#  '.',
#  '④',
#  '정당',
#  '의',
#  '목적',
#  '이나',
#  '활동',
#  '이',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '위배',
#  '되',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '정부',
#  '는',
#  '헌법',
#  '재판소',
#  '에',
#  '그',
#  '해산',
#  '을',
#  '제소',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '고',
#  ',',
#  '정당',
#  '은',
#  '헌법',
#  '재판소',
#  '의',
#  '심판',
#  '에',
#  '의하',
#  '여',
#  '해산',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '9',
#  '조',
#  '국가',
#  '는',
#  '전통문화',
#  '의',
#  '계승',
#  '·',
#  '발전',
#  '과',
#  '민족',
#  '문화',
#  '의',
#  '창달',
#  '에',
#  '노력',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '장',
#  '국민',
#  '의',
#  '권리',
#  '와',
#  '의무',
#  '제',
#  '10',
#  '조',
#  '모든',
#  '국민',
#  '은',
#  '인간',
#  '으로서',
#  '의',
#  '존엄',
#  '과',
#  '가치',
#  '를',
#  '가지',
#  '며',
#  ',',
#  '행복',
#  '을',
#  '추구',
#  '하',
#  'ㄹ',
#  '권리',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '국가',
#  '는',
#  '개인',
#  '이',
#  '가지',
#  '는',
#  '불가침',
#  '의',
#  '기본적',
#  '인권',
#  '을',
#  '확인',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '보장',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '11',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '법',
#  '앞',
#  '에',
#  '평등',
#  '하',
#  '다',
#  '.',
#  '누구',
#  '든지',
#  '성별',
#  '·',
#  '종교',
#  '또는',
#  '사회적',
#  '신분',
#  '에',
#  '의하',
#  '여',
#  '정치적',
#  '·',
#  '경제적',
#  '·',
#  '사회적',
#  '·',
#  '문화적',
#  '생활',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '차별',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '사회적',
#  '특수',
#  '계급',
#  '의',
#  '제도',
#  '는',
#  '인정',
#  '되',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '형태',
#  '로',
#  '도',
#  '이',
#  '를',
#  '창설',
#  '하',
#  'ㄹ',
#  '수',
#  '없',
#  '다',
#  '.',
#  '③',
#  '훈장',
#  '등',
#  '의',
#  '영전',
#  '은',
#  '이르',
#  'ㄹ',
#  '받',
#  '은',
#  '자',
#  '에게',
#  '만',
#  '효력',
#  '이',
#  '있',
#  '고',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '특권',
#  '도',
#  '이에',
#  '따르',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '12',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '신체',
#  '의',
#  '자유',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '누구',
#  '든지',
#  '법률',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '·',
#  '수색',
#  '또는',
#  '심문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '법률',
#  '과',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '처벌',
#  '·',
#  '보안',
#  '처분',
#  '또는',
#  '강제',
#  '노역',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '모든',
#  '국민',
#  '은',
#  '고문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '형',
#  '사상',
#  '자기',
#  '에게',
#  '불리',
#  '하',
#  'ㄴ',
#  '진술',
#  '을',
#  '강요',
#  '당하',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '③',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '또는',
#  '수색',
#  '을',
#  '하',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '따르',
#  '아',
#  '검사',
#  '의',
#  '신청',
#  '에',
#  '의하',
#  '여',
#  '법관',
#  '이',
#  '발부',
#  '하',
#  'ㄴ',
#  '영장',
#  '을',
#  '제시',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '다만',
#  ',',
#  '현행',
#  '범인',
#  '이',
#  'ㄴ',
#  '경우',
#  '와',
#  '장기',
#  '3',
#  '년',
#  '이상',
#  '의',
#  '형',
#  '에',
#  '해당',
#  '하',
#  '는',
#  '죄',
#  '를',
#  '범하',
#  '고',
#  '도피',
#  '또는',
#  '증거',
#  '인멸',
#  '의',
#  '염려',
#  '가',
#  '있',
#  '을',
#  '때',
#  '에',
#  '는',
#  ...]

# %%
finder = collocations.BigramCollocationFinder.from_words(tags)

for row in finder.nbest(measure.pmi, 5): #pmi의 척도로 상위 5개의 bigram tag를 갖고옴
    print(row) 
#이를 통해서 각 태그에 대해서 어떠한 태그 뒤에는 어떤 태그가 많이 나온다는 것을 알 수 있다.
# Out:
# ('XR', 'XSA')
# ('JKC', 'VCN')
# ('EPT', 'EPT')
# ('VCN', 'ECD')
# ('ECD', 'VX')

# %%
finder = collocations.BigramCollocationFinder.from_words(words)

for row in finder.nbest(measure.pmi, 5): #pmi의 척도로 상위 5개의 bigram 단어를 갖고옴
    print(row) 
#이를 통해서 각 단어에 대해서 어떠한 단어 뒤에는 어떤 단어가 많이 나온다는 것을 알 수 있다.
# 많이 나오는 단어 쌍을 알 수 있다.
# Out:
# ('가부', '동수')
# ('강제', '노역')
# ('경자', '유전')
# ('공무', '담임')
# ('공중', '도덕')

# %% [markdown]
# ### Word Cloud 생성

# %%
ko.vocab() 
# 해당 token들에 대해서 빈도수를 value로 가지는 dict타입 단어장 만들어준다.
# Out:
# FreqDist({'대한민국': 11,
#           '헌법': 69,
#           '유구': 1,
#           '하': 457,
#           'ㄴ': 234,
#           '역사': 1,
#           '와': 42,
#           '전통': 1,
#           '에': 328,
#           '빛나': 1,
#           '는': 281,
#           '우리': 3,
#           '대하': 19,
#           '국민': 69,
#           '은': 195,
#           '3': 24,
#           '·': 145,
#           '1': 28,
#           '운동': 3,
#           '으로': 57,
#           '건립': 1,
#           '되': 113,
#           '임시': 3,
#           '정부': 23,
#           '의': 532,
#           '법통': 1,
#           '과': 82,
#           '불의': 2,
#           '항거': 1,
#           '4': 14,
#           '19': 2,
#           '민주': 6,
#           '이념': 1,
#           '을': 232,
#           '계승': 2,
#           '고': 39,
#           ',': 101,
#           '조국': 3,
#           '개혁': 1,
#           '평화적': 4,
#           '통일': 9,
#           '사명': 2,
#           '입각': 2,
#           '여': 149,
#           '정의': 2,
#           '인도': 1,
#           '동포애': 1,
#           '로써': 5,
#           '민족': 3,
#           '단결': 1,
#           '공고히': 1,
#           '모든': 37,
#           '사회적': 5,
#           '폐습': 1,
#           '를': 135,
#           '타파': 1,
#           '며': 45,
#           '자율': 2,
#           '조화': 2,
#           '바탕': 1,
#           '자유': 21,
#           '민주적': 4,
#           '기본': 8,
#           '질서': 8,
#           '더욱': 1,
#           '확고히': 1,
#           '하여': 3,
#           '정치': 4,
#           '경제': 18,
#           '사회': 4,
#           '문화': 3,
#           '영역': 4,
#           '있': 99,
#           '어서': 9,
#           '각인': 1,
#           '기회': 4,
#           '균등': 4,
#           '히': 1,
#           '능력': 3,
#           '최고': 3,
#           '도로': 1,
#           '발휘': 1,
#           '게': 6,
#           '권리': 21,
#           '따르': 7,
#           '책임': 5,
#           '의무': 20,
#           '완수': 1,
#           '안': 15,
#           '생활': 8,
#           '향상': 4,
#           '기하': 1,
#           '밖': 1,
#           '항구적': 1,
#           '이': 192,
#           '세계': 1,
#           '평화': 5,
#           '인류': 1,
#           '공영': 1,
#           '이바지': 1,
#           'ㅁ': 6,
#           '으로써': 4,
#           '들': 2,
#           '자손': 1,
#           '안전': 11,
#           '행복': 2,
#           '영원히': 1,
#           '확보': 1,
#           'ㄹ': 141,
#           '것': 7,
#           '다짐': 1,
#           '면서': 1,
#           '1948': 1,
#           '년': 12,
#           '7': 4,
#           '월': 3,
#           '12': 3,
#           '일': 19,
#           '제정': 8,
#           '8': 4,
#           '차': 3,
#           '걸치': 1,
#           '어': 13,
#           '개정': 9,
#           '이제': 1,
#           '국회': 55,
#           '의결': 16,
#           '거치': 2,
#           '투표': 8,
#           '의하': 83,
#           'ㄴ다': 243,
#           '.': 359,
#           '저': 155,
#           '장': 15,
#           '총': 1,
#           '강': 1,
#           '제': 20,
#           '조': 136,
#           '①': 78,
#           '공화국': 1,
#           '다': 88,
#           '②': 78,
#           '주권': 2,
#           '에게': 10,
#           '권력': 1,
#           '부터': 13,
#           '나오': 1,
#           '2': 19,
#           '요건': 1,
#           '법률': 121,
#           '로': 62,
#           '정하': 88,
#           '국가': 73,
#           '바': 37,
#           '재외': 1,
#           '보호': 15,
#           '질': 13,
#           '영토': 2,
#           '한반도': 1,
#           '그': 46,
#           '부속': 1,
#           '도': 8,
#           '서로': 1,
#           '지향': 2,
#           '정책': 14,
#           '수립': 7,
#           '이르': 14,
#           '추진': 1,
#           '5': 10,
#           '국제': 3,
#           '유지': 7,
#           '노력': 13,
#           '침략': 1,
#           '적': 2,
#           '전쟁': 1,
#           '부인': 1,
#           '국': 21,
#           '군은': 1,
#           '보장': 24,
#           '국토': 3,
#           '방위': 2,
#           '신성': 1,
#           '수행': 4,
#           '정치적': 5,
#           '중립성': 3,
#           '준수': 2,
#           '6': 10,
#           '체결': 4,
#           '공포': 11,
#           '조약': 11,
#           '일반적': 1,
#           '승인': 6,
#           '법규': 1,
#           '국내': 2,
#           '법과': 1,
#           '같': 4,
#           '효력': 9,
#           '가지': 32,
#           '외국인': 1,
#           '국제법': 1,
#           '지위': 3,
#           '가': 45,
#           '공무원': 17,
#           '전체': 1,
#           '봉사자': 1,
#           '신분': 3,
#           '정당': 14,
#           '설립': 1,
#           '복수': 1,
#           '정당제': 1,
#           '목적': 4,
#           '조직': 18,
#           '활동': 3,
#           '어야': 21,
#           '의사': 2,
#           '형성': 1,
#           '참여': 1,
#           '는데': 1,
#           '필요': 31,
#           '③': 45,
#           '받': 41,
#           '으며': 6,
#           '운영': 5,
#           '자금': 1,
#           '보조': 1,
#           '수': 88,
#           '④': 20,
#           '이나': 10,
#           '위배': 3,
#           '때': 55,
#           '재판소': 14,
#           '해산': 5,
#           '제소': 3,
#           '심판': 12,
#           '9': 4,
#           '전통문화': 1,
#           '발전': 5,
#           '창달': 2,
#           '여야': 31,
#           '10': 5,
#           '인간': 3,
#           '으로서': 5,
#           '존엄': 2,
#           '가치': 1,
#           '추구': 1,
#           '개인': 3,
#           '불가침': 1,
#           '기본적': 1,
#           '인권': 1,
#           '확인': 1,
#           '11': 3,
#           '법': 6,
#           '앞': 2,
#           '평등': 4,
#           '누구': 6,
#           '든지': 6,
#           '성별': 1,
#           '종교': 3,
#           '또는': 69,
#           '경제적': 2,
#           '문화적': 1,
#           '차별': 2,
#           '지': 57,
#           '아니하': 53,
#           '특수': 1,
#           '계급': 1,
#           '제도': 5,
#           '인정': 8,
#           '어떠하': 2,
#           '형태': 1,
#           '창설': 1,
#           '없': 30,
#           '훈장': 2,
#           '등': 6,
#           '영전': 3,
#           '자': 10,
#           '만': 1,
#           '특권': 1,
#           '이에': 5,
#           '신체': 3,
#           '고는': 12,
#           '체포': 9,
#           '구속': 8,
#           '압수': 3,
#           '수색': 3,
#           '심문': 1,
#           '적법': 2,
#           '절차': 9,
#           '처벌': 3,
#           '보안': 1,
#           '처분': 12,
#           '강제': 1,
#           '노역': 1,
#           '고문': 2,
#           '형': 4,
#           '사상': 6,
#           '자기': 2,
#           '불리': 3,
#           '진술': 5,
#           '강요': 1,
#           '당하': 9,
#           '아': 7,
#           '검사': 4,
#           '신청': 2,
#           '법관': 11,
#           '발부': 2,
#           '영장': 4,
#           '제시': 2,
#           '다만': 11,
#           '현행': 3,
#           '범인': 3,
#           '경우': 17,
#           '장기': 1,
#           '이상': 18,
#           '해당': 1,
#           '죄': 4,
#           '범하': 2,
#           '도피': 1,
#           '증거': 3,
#           '인멸': 1,
#           '염려': 2,
#           '사후': 1,
#           '청구': 6,
#           '즉시': 2,
#           '변호인': 4,
#           '조력': 2,
#           '형사': 6,
#           '피고인': 6,
#           '스스로': 1,
#           '구하': 1,
#           '붙이': 5,
#           '⑤': 11,
#           '이유': 7,
#           '있음': 1,
#           '고지': 1,
#           '자의': 2,
#           '가족': 2,
#           '일시': 1,
#           '장소': 1,
#           '지체': 6,
#           '없이': 8,
#           '통지': 1,
#           '⑥': 6,
#           '적부': 1,
#           '심사': 5,
#           '법원': 17,
#           '⑦': 3,
#           '자백': 2,
#           '폭행': 1,
#           '협박': 1,
#           '부당': 2,
#           '장기화': 1,
#           '기망': 1,
#           '기타': 26,
#           '방법': 4,
#           '아니': 11,
#           '라고': 1,
#           '정식': 1,
#           '재판': 15,
#           '유일': 1,
#           '유죄': 2,
#           '삼': 1,
#           '거나': 20,
#           '13': 2,
#           '행위시': 1,
#           '범죄': 4,
#           '구성': 8,
#           '행위': 8,
#           '소': 1,
#           '추': 1,
#           '동일': 1,
#           '거듭': 1,
#           '소급': 1,
#           '입법': 2,
#           '참정권': 1,
#           '제한': 7,
#           '재산권': 4,
#           '박탈': 1,
#           '친족': 1,
#           '인하': 6,
#           '불': 2,
#           '이익': 5,
#           '처우': 2,
#           '14': 2,
#           '거주': 1,
#           '이전': 2,
#           '15': 4,
#           '직업': 1,
#           '선택': 1,
#           '16': 2,
#           '주거': 3,
#           '침해': 6,
#           '나': 12,
#           '17': 2,
#           '사생활': 1,
#           '비밀': 4,
#           '18': 1,
#           '통신': 2,
#           '양심': 3,
#           '20': 3,
#           '국교': 1,
#           '분리': 1,
#           '21': 1,
#           '언론': 5,
#           '출판': 5,
#           '집회': 12,
#           '결사': 3,
#           '허': 1,
#           '검열': 1,
#           '허가': 1,
#           '방송': 1,
#           '시설': 2,
#           '기준': 2,
#           '신문': 1,
#           '기능': 1,
#           '기': 16,
#           '위하': 33,
#           '사항': 23,
#           '타인': 4,
#           '명예': 2,
#           '공중': 1,
#           '도덕': 1,
#           '윤리': 1,
#           '여서': 1,
#           '알': 1,
#           '니': 1,
#           '피해자': 2,
#           '대': 1,
#           '피해': 2,
#           '배상': 3,
#           '22': 1,
#           '학문': 1,
#           '예술': 1,
#           '저작자': 1,
#           '발명가': 1,
#           '과학': 2,
#           '기술자': 1,
#           '예술가': 1,
#           '23': 1,
#           '내용': 5,
#           '한계': 1,
#           '행사': 3,
#           '공공': 8,
#           '복리': 4,
#           '적합': 1,
#           '도록': 4,
#           '수용': 1,
#           '사용': 1,
#           '및': 25,
#           '보상': 4,
#           '정': 5,
#           '지급': 1,
#           '24': 1,
#           '선거권': 4,
#           '25': 2,
#           '공무': 1,
#           '담임': 1,
#           '권': 1,
#           '26': 1,
#           '기관': 10,
#           '문서': 3,
#           '청원': 3,
#           '27': 1,
#           '군인': 5,
#           '군무원': 3,
#           '에서': 24,
#           '중대': 5,
#           '군': 3,
#           '기밀': 1,
#           '초병': 2,
#           '초소': 2,
#           '유독': 2,
#           '음식물': 2,
#           '공급': 2,
#           '포로': 2,
#           '군용물': 1,
#           '관하': 53,
#           '중': 10,
#           '비상계엄': 2,
#           '선포': 4,
#           '제외': 5,
#           '군사': 10,
#           '신속': 1,
#           '상당': 1,
#           '한': 6,
#           '공개': 7,
#           '판결': 4,
#           '확정': 8,
#           '까': 1,
#           '무죄': 2,
#           '추정': 1,
#           '당해': 1,
#           '사건': 1,
#           '28': 1,
#           '피의자': 1,
#           '구금': 3,
#           '었': 2,
#           '더': 2,
#           '자가': 3,
#           '불기소': 1,
#           '29': 2,
#           '직무': 19,
#           '상': 8,
#           '불법': 2,
#           '손해': 2,
#           '단체': 16,
#           '자신': 1,
#           '면제': 2,
#           '경찰': 1,
#           '전투': 1,
#           '훈련': 1,
#           '집행': 4,
#           '관련': 2,
#           '외': 2,
#           '30': 5,
#           '생명': 1,
#           '구조': 2,
#           '31': 1,
#           '교육': 10,
#           '자녀': 1,
#           '적어도': 1,
#           '초등': 1,
#           '무상': 1,
#           '자주성': 1,
#           '전문': 1,
#           '성': 1,
#           '대학': 1,
#           '자율성': 1,
#           '평생': 2,
#           '진흥': 1,
#           '학교': 2,
#           '포함': 2,
#           '재정': 5,
#           '교원': 1,
#           '적인': 2,
#           '32': 1,
#           '근로': 9,
#           '근로자': 4,
#           '고용': 2,
#           '증진': 3,
#           '적정': 2,
#           '임금': 2,
#           '최저': 1,
#           '임금제': 1,
#           '시행': 12,
#           '조건': 4,
#           '주의': 1,
#           '원칙': 2,
#           '존엄성': 1,
#           '여자': 2,
#           '특별': 6,
#           '연소자': 1,
#           '유공자': 1,
#           '상이': 1,
#           '군경': 2,
#           '전몰': 1,
#           '유가족': 1,
#           '우선적': 1,
#           '부여받': 1,
#           '33': 1,
#           '자주적': 1,
#           '단결권': 2,
#           '교섭권': 2,
#           '행동권': 3,
#           '한하': 7,
#           '주요': 1,
#           '산업체': 1,
#           '종사': 1,
#           '34': 1,
#           '답': 1,
#           '복지': 2,
#           '권익': 1,
#           '노인과': 1,
#           '청소년': 1,
#           '복': 1,
#           '실시': 3,
#           '장애자': 1,
#           '질병': 1,
#           '노령': 1,
#           '사유': 3,
#           '재해': 1,
#           '예방': 1,
#           '위험': 1,
#           '35': 1,
#           '건강': 1,
#           '쾌적': 2,
#           '환경': 2,
#           '보전': 3,
#           '환경권': 1,
#           '주택': 1,
#           '개발': 6,
#           '통하': 3,
#           '36': 1,
#           '혼인': 1,
#           '양성': 1,
#           '기초': 1,
#           '성립': 1,
#           '모성': 1,
#           '보건': 1,
#           '37': 1,
#           '열거': 1,
#           '경시': 1,
#           '본질적': 1,
#           '38': 1,
#           '납세': 1,
#           '39': 1,
#           '국방': 2,
#           '병역': 1,
#           '이행': 2,
#           '40': 4,
#           '입법권': 1,
#           '속하': 5,
#           '41': 1,
#           '보통': 2,
#           '직접': 2,
#           '선거': 26,
#           '선출': 7,
#           '국회의원': 18,
#           '200': 1,
#           '인': 9,
#           '선거구': 1,
#           '비례': 1,
#           '대표제': 1,
#           '42': 1,
#           '임기': 18,
#           '43': 1,
#           '직': 2,
#           '겸하': 2,
#           '44': 1,
#           '회기': 6,
#           '동의': 9,
#           '전': 6,
#           '요구': 13,
#           '으면': 1,
#           '석방': 1,
#           '45': 1,
#           '행': 1,
#           '발언': 2,
#           '표결': 1,
#           '지지': 1,
#           '46': 1,
#           '청렴': 1,
#           '우선': 1,
#           '행하': 4,
#           '남용': 2,
#           '기업체': 2,
#           '계약': 3,
#           '재': 1,
#           '산상': 1,
#           '직위': 1,
#           '취득': 2,
#           '알선': 1,
#           '47': 1,
#           '회의': 42,
#           '매년': 2,
#           '회': 1,
#           '임시회': 2,
#           '대통령': 84,
#           '재적': 14,
#           '의원': 23,
#           '분': 8,
#           '정기': 1,
#           '100': 2,
#           '초과': 1,
#           '기간': 5,
#           '명시': 1,
#           '48': 1,
#           '의장': 6,
#           '인과': 2,
#           '부의장': 1,
#           '49': 1,
#           '규정': 6,
#           '과반수': 10,
#           '출석': 12,
#           '찬성': 12,
#           '가부': 1,
#           '동수': 1,
#           '부결': 1,
#           '보': 6,
#           '50': 1,
#           '하다': 2,
#           '공표': 1,
#           '51': 1,
#           '제출': 8,
#           '법률안': 7,
#           '의안': 1,
#           '못하': 4,
#           '폐기': 1,
#           '만료': 3,
#           '그러하': 2,
#           '52': 1,
#           '53': 1,
#           '이송': 2,
#           '이내': 6,
#           '이의': 2,
#           '항': 22,
#           '내': 2,
#           '서': 1,
#           '환부': 1,
#           '재의': 5,
#           '폐회': 1,
#           '또한': 2,
#           '일부': 1,
#           '또': 1,
#           '수정': 1,
#           '반': 1,
#           '수의': 1,
#           '전과': 1,
#           '면': 8,
#           '로서': 3,
#           '후': 6,
#           '날': 2,
#           '경과': 1,
#           '발생': 2,
#           '54': 1,
#           '예산안': 5,
#           '심의': 5,
#           '회계': 6,
#           '연도': 5,
#           '마다': 1,
#           '편성': 3,
#           '개시': 5,
#           '90': 2,
#           '까지': 10,
#           '새': 2,
#           '롭': 1,
#           '예산': 5,
#           '안이': 1,
#           '다음': 4,
#           '경비': 3,
#           '전년도': 1,
#           '준하': 2,
#           '설치': 5,
#           '지출': 4,
#           '이미': 1,
#           '사업': 1,
#           '계속': 3,
#           '55': 1,
#           '넘': 1,
#           '연한': 1,
#           '비로서': 1,
#           '얻': 18,
#           '예비비': 2,
#           '총액': 1,
#           '차기': 1,
#           '56': 1,
#           '변경': 3,
#           '가하': 1,
#           '추가': 1,
#           '경정': 1,
#           '57': 1,
#           '각': 4,
#           '항의': 1,
#           '금액': 1,
#           '증가': 1,
#           '비목': 1,
#           '58': 1,
#           '국채': 1,
#           '모집': 1,
#           '예산외': 1,
#           '부담': 4,
#           '려': 1,
#           '미리': 1,
#           '59': 1,
#           '조세': 1,
#           '종목': 1,
#           '세율': 1,
#           '60': 3,
#           '상호': 3,
#           '원조': 1,
#           '중요': 10,
#           '우호': 1,
#           '통상': 1,
#           '항해': 1,
#           '제약': 1,
#           '강화': 3,
#           '재정적': 1,
#           '지우': 1,
#           '비준': 2,
#           '동의권': 2,
#           '선전': 3,
#           '포고': 2,
#           '국군': 2,
#           '외국': 3,
#           '파견': 2,
#           '군대': 1,
#           '주류': 1,
#           '61': 1,
#           '국정': 7,
#           '감사': 7,
#           '특정': 1,
#           '사안': 1,
#           '조사': 2,
#           '서류': 1,
#           '증인': 1,
#           '증언': 1,
#           '의견': 3,
#           '62': 1,
#           '국무': 30,
#           '총리': 6,
#           '위원': 31,
#           '위원회': 7,
#           '처리': 6,
#           '상황': 2,
#           '질문': 1,
#           '응답': 1,
#           '국무총리': 13,
#           '답변': 2,
#           '하여금': 1,
#           '63': 1,
#           '해임': 3,
#           '건의': 3,
#           '발의': 4,
#           '64': 1,
#           '저촉': 4,
#           '범위': 16,
#           '내부': 4,
#           '규율': 4,
#           '규칙': 6,
#           '자격': 6,
#           '징계': 2,
#           '제명': 1,
#           '려면': 2,
#           '65': 1,
#           '행정': 15,
#           '각부': 9,
#           '재판관': 8,
#           '중앙': 3,
#           '관리': 13,
#           '감사원장': 2,
#           '탄핵': 11,
#           '소추': 5,
#           '결': 1,
#           '권한': 11,
#           '정지': 1,
#           '결정': 6,
#           '공직': 1,
#           '파면': 1,
#           '그치': 1,
#           '그러': 1,
#           '민': 1,
#           '절': 3,
#           '66': 1,
#           '원수': 1,
#           '대표': 1,
#           '독립': 2,
#           '계속성': 1,
#           '수호': 1,
#           '책무': 1,
#           '성실': 1,
#           '행정권': 1,
#           '수반': 1,
#           '67': 1,
#           '득표자': 1,
#           '과반': 1,
#           '수가': 1,
#           '다수': 1,
#           '표': 1,
#           '당선': 2,
#           '자로': 1,
#           '후보자': 2,
#           '득표수': 1,
#           '총수': 1,
#           '피': 1,
#           '선거일': 1,
#           '현재': 1,
#           '세': 1,
#           '달하': 1,
#           '68': 1,
#           '70': 2,
#           '내지': 1,
#           '후임자': 4,
#           '궐': 2,
#           '위': 4,
#           '당선자': 1,
#           '사망': 1,
#           '상실': 2,
#           '69': 1,
#           '취임': 1,
#           '즈음': 1,
#           '선서': 2,
#           '"': 2,
#           '보위': 2,
#           '직책': 1,
#           '성실히': 1,
#           '엄숙히': 1,
#           'ㅂ니다': 1,
#           '중임': 6,
#           '71': 1,
#           '사고': 1,
#           '정한': 1,
#           '순서': 1,
#           '대행': 1,
#           '72': 1,
#           '외교': 2,
#           '73': 1,
#           '사절': 1,
#           '신임': 1,
#           '접수': 1,
#           '74': 1,
#           '통수': 1,
#           '군의': 1,
#           '75': 1,
#           '구체적': 1,
#           '위임': 3,
#           '대통령령': 3,
#           '발하': 4,
#           '76': 1,
#           '내우': 1,
#           '외환': 2,
#           '천재': 1,
#           '지변': 1,
#           '상의': 4,
#           '위기': 1,
#           '안녕': 3,
#           '긴급': 4,
#           '조치': 3,
#           '기다리': 1,
#           '여유': 1,
#           '최소한': 1,
#           '관': 5,
#           '명령': 9,
#           '안위': 1,
#           '관계': 4,
#           '교전': 1,
#           '상태': 1,
#           '불가능': 1,
#           '그때': 1,
#           '폐지': 1,
#           '당연히': 1,
#           '회복': 1,
#           '77': 1,
#           '전시': 1,
#           '사변': 1,
#           '비상사태': 1,
#           '병력': 1,
#           '응하': 6,
#           '계엄': 8,
#           '비상': 2,
#           '통고': 1,
#           '해제': 3,
#           '78': 1,
#           '임면': 1,
#           '79': 1,
#           '사면': 3,
#           '감형': 3,
#           '복권': 3,
#           '명하': 2,
#           '일반': 2,
#           '사': 1,
#           '80': 1,
#           '수여': 2,
#           '81': 1,
#           '서한': 1,
#           '표시': 1,
#           '82': 1,
#           '국법': 1,
#           '부서': 1,
#           '83': 1,
#           '공사': 1,
#           '84': 1,
#           '내란': 1,
#           '재직': 1,
#           '85': 1,
#           '전직': 1,
#           '예우': 1,
#           '행정부': 1,
#           '86': 1,
#           '임명': 19,
#           '보좌': 2,
#           '명': 1,
#           '통할': 1,
#           '현역': 2,
#           '면하': 2,
#           '87': 1,
#           '제청': 6,
#           '구성원': 1,
#           '88': 1,
#           '이하': 2,
#           '부의': 1,
#           '장이': 1,
#           '89': 1,
#           '계획': 5,
#           '대외': 3,
#           '개정안': 5,
#           '조약안': 1,
#           '결산': 3,
#           '국유': 2,
#           '재산': 2,
#           '간의': 2,
#           '획정': 1,
#           '정부안': 1,
#           '배정': 1,
#           '평가': 1,
#           '분석': 1,
#           '조정': 3,
#           '회부': 1,
#           '검찰': 1,
#           '총장': 3,
#           '합동': 1,
#           ...})

# %%
with open("cloud.csv", "w", encoding="utf-8") as f:
    f.write("word, freq\n") 
    for k,v in ko.vocab().items():
        f.write("{0}, {1}\n".format(k,v))

# %%
# !pip install simplejson
# !pip install pygame
# !pip install pytagcloud #단어 빈도에 따라 크기, 색을 다르게 하여 이미지로 저장해줌.
# Out:
# Requirement already satisfied: simplejson in d:\anaconda3\lib\site-packages (3.16.0)
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: pygame in d:\anaconda3\lib\site-packages (1.9.4)
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Invalid requirement: '#단어'
# Traceback (most recent call last):
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\packaging\requirements.py", line 93, in __init__
#     req = REQUIREMENT.parseString(requirement_string)
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1632, in parseString
#     raise exc
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1622, in parseString
#     loc, tokens = self._parse( instring, 0 )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1379, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3395, in parseImpl
#     loc, exprtokens = e._parse( instring, loc, doActions )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1379, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3717, in parseImpl
#     return self.expr._parse( instring, loc, doActions, callPreParse=False )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1379, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 3378, in parseImpl
#     loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 1383, in _parseNoCache
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\pyparsing.py", line 2689, in parseImpl
#     raise ParseException(instring, loc, self.errmsg, self)
# pip._vendor.pyparsing.ParseException: Expected W:(abcd...) (at char 0), (line:1, col:1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 253, in from_line
#     req = Requirement(req)
#   File "d:\anaconda3\lib\site-packages\pip\_vendor\packaging\requirements.py", line 97, in __init__
#     requirement_string[e.loc:e.loc + 8]))
# pip._vendor.packaging.requirements.InvalidRequirement: Invalid requirement, parse error at "'#단어'"
#
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
wordList = [k for (k,v) in kkma.pos(corpus) if v.startswith("NN")]  # 형태소 분석한 결과 중에 태그가 NN으로 시작한다면 받아옴

# %%
wordList
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '역사',
#  '전통',
#  '우리',
#  '국민',
#  '운동',
#  '건립',
#  '대한민국',
#  '임시',
#  '정부',
#  '법통',
#  '불의',
#  '항거',
#  '민주',
#  '이념',
#  '계승',
#  '조국',
#  '민주',
#  '개혁',
#  '평화적',
#  '통일',
#  '사명',
#  '입각',
#  '정의',
#  '인도',
#  '동포애',
#  '민족',
#  '단결',
#  '사회적',
#  '폐습',
#  '불의',
#  '타파',
#  '자율',
#  '조화',
#  '바탕',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '정치',
#  '경제',
#  '사회',
#  '문화',
#  '영역',
#  '각인',
#  '기회',
#  '균등',
#  '히',
#  '능력',
#  '최고',
#  '도로',
#  '발휘',
#  '자유',
#  '권리',
#  '책임',
#  '의무',
#  '완수',
#  '안',
#  '국민',
#  '생활',
#  '균등',
#  '향상',
#  '밖',
#  '항구적',
#  '세계',
#  '평화',
#  '인류',
#  '공영',
#  '이바지',
#  '자손',
#  '안전',
#  '자유',
#  '행복',
#  '확보',
#  '것',
#  '다짐',
#  '년',
#  '월',
#  '일',
#  '제정',
#  '차',
#  '개정',
#  '헌법',
#  '이제',
#  '국회',
#  '의결',
#  '국민',
#  '투표',
#  '개정',
#  '장',
#  '강',
#  '제',
#  '대한민국',
#  '민주',
#  '공화국',
#  '대한민국',
#  '주권',
#  '국민',
#  '권력',
#  '국민',
#  '대한민국',
#  '국민',
#  '요건',
#  '법률',
#  '국가',
#  '법률',
#  '바',
#  '재외',
#  '국민',
#  '보호',
#  '의무',
#  '조',
#  '대한민국',
#  '영토',
#  '한반도',
#  '부속',
#  '조',
#  '대한민국',
#  '통일',
#  '지향',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '입각',
#  '평화적',
#  '통일',
#  '정책',
#  '수립',
#  '추진',
#  '대한민국',
#  '국제',
#  '평화',
#  '유지',
#  '노력',
#  '침략',
#  '전쟁',
#  '부인',
#  '국',
#  '군은',
#  '국가',
#  '안전',
#  '보장',
#  '국토',
#  '방위',
#  '신성',
#  '의무',
#  '수행',
#  '사명',
#  '정치적',
#  '중립성',
#  '준수',
#  '헌법',
#  '체결',
#  '공포',
#  '조약',
#  '일반적',
#  '승인',
#  '국제',
#  '법규',
#  '국내',
#  '법과',
#  '효력',
#  '외국인',
#  '국제법',
#  '조약',
#  '바',
#  '지위',
#  '보장',
#  '공무원',
#  '국민',
#  '전체',
#  '봉사자',
#  '국민',
#  '책임',
#  '공무원',
#  '신분',
#  '정치적',
#  '중립성',
#  '법률',
#  '바',
#  '보장',
#  '정당',
#  '설립',
#  '자유',
#  '복수',
#  '정당제',
#  '보장',
#  '정당',
#  '목적',
#  '조직',
#  '활동',
#  '민주적',
#  '국민',
#  '정치적',
#  '의사',
#  '형성',
#  '참여',
#  '필요',
#  '조직',
#  '정당',
#  '법률',
#  '바',
#  '국가',
#  '보호',
#  '국가',
#  '법률',
#  '바',
#  '정당',
#  '운영',
#  '필요',
#  '자금',
#  '보조',
#  '수',
#  '정당',
#  '목적',
#  '활동',
#  '민주적',
#  '기본',
#  '질서',
#  '위배',
#  '때',
#  '정부',
#  '헌법',
#  '재판소',
#  '해산',
#  '제소',
#  '수',
#  '정당',
#  '헌법',
#  '재판소',
#  '심판',
#  '해산',
#  '조',
#  '국가',
#  '전통문화',
#  '계승',
#  '발전',
#  '민족',
#  '문화',
#  '창달',
#  '노력',
#  '장',
#  '국민',
#  '권리',
#  '의무',
#  '제',
#  '조',
#  '국민',
#  '인간',
#  '존엄',
#  '가치',
#  '행복',
#  '추구',
#  '권리',
#  '국가',
#  '개인',
#  '불가침',
#  '기본적',
#  '인권',
#  '확인',
#  '보장',
#  '의무',
#  '모든',
#  '국민',
#  '법',
#  '앞',
#  '평등',
#  '성별',
#  '종교',
#  '사회적',
#  '신분',
#  '정치적',
#  '경제적',
#  '사회적',
#  '문화적',
#  '생활',
#  '영역',
#  '차별',
#  '사회적',
#  '특수',
#  '계급',
#  '제도',
#  '인정',
#  '형태',
#  '창설',
#  '수',
#  '훈장',
#  '등',
#  '영전',
#  '자',
#  '효력',
#  '특권',
#  '모든',
#  '국민',
#  '신체',
#  '자유',
#  '법률',
#  '체포',
#  '구속',
#  '압수',
#  '수색',
#  '심문',
#  '법률',
#  '적법',
#  '절차',
#  '처벌',
#  '보안',
#  '처분',
#  '강제',
#  '노역',
#  '모든',
#  '국민',
#  '고문',
#  '형',
#  '사상',
#  '불리',
#  '진술',
#  '강요',
#  '체포',
#  '구속',
#  '압수',
#  '수색',
#  '때',
#  '적법',
#  '절차',
#  '검사',
#  '신청',
#  '법관',
#  '발부',
#  '영장',
#  '제시',
#  '현행',
#  '범인',
#  '경우',
#  '장기',
#  '년',
#  '이상',
#  '형',
#  '해당',
#  '죄',
#  '도피',
#  '증거',
#  '인멸',
#  '염려',
#  '때',
#  '사후',
#  '영장',
#  '청구',
#  '수',
#  '체포',
#  '구속',
#  '때',
#  '즉시',
#  '변호인',
#  '조력',
#  '권리',
#  '형사',
#  '피고인',
#  '변호인',
#  '수',
#  '때',
#  '법률',
#  '바',
#  '국가',
#  '변호인',
#  '체포',
#  '구속',
#  '이유',
#  '변호인',
#  '조력',
#  '권리',
#  '있음',
#  '고지',
#  '체포',
#  '구속',
#  '체포',
#  '구속',
#  '자의',
#  '가족',
#  '등',
#  '법률',
#  '자',
#  '이유',
#  '일시',
#  '장소',
#  '지체',
#  '통지',
#  '체포',
#  '구속',
#  '때',
#  '적부',
#  '심사',
#  '법원',
#  '청구',
#  '권리',
#  '피고인',
#  '자백',
#  '고문',
#  '폭행',
#  '협박',
#  '구속',
#  '부당',
#  '장기화',
#  '기망',
#  '기타',
#  '방법',
#  '자의',
#  '진술',
#  '것',
#  '인정',
#  '때',
#  '정식',
#  '재판',
#  '피고인',
#  '자백',
#  '불리',
#  '유일',
#  '증거',
#  '때',
#  '유죄',
#  '증거',
#  '이유',
#  '처벌',
#  '수',
#  '모든',
#  '국민',
#  '행위시',
#  '법률',
#  '범죄',
#  '구성',
#  '행위',
#  '소',
#  '추',
#  '동일',
#  '범죄',
#  '처벌',
#  '모든',
#  '국민',
#  '소급',
#  '입법',
#  '참정권',
#  '제한',
#  '재산권',
#  '박탈',
#  '모든',
#  '국민',
#  '행위',
#  '친족',
#  '행위',
#  '불',
#  '이익',
#  '처우',
#  '조',
#  '국민',
#  '거주',
#  '이전',
#  '자유',
#  '조',
#  '국민',
#  '직업',
#  '선택',
#  '자유',
#  '조',
#  '국민',
#  '주거',
#  '자유',
#  '침해',
#  '주거',
#  '압수',
#  '수색',
#  '때',
#  '검사',
#  '신청',
#  '법관',
#  '발부',
#  '영장',
#  '제시',
#  '조',
#  '국민',
#  '사생활',
#  '비밀',
#  '자유',
#  '침해',
#  '조',
#  '국민',
#  '통신',
#  '비밀',
#  '침해',
#  '조',
#  '국민',
#  '양심',
#  '자유',
#  '모든',
#  '국민',
#  '종교',
#  '자유',
#  '국교',
#  '인정',
#  '종교',
#  '정치',
#  '분리',
#  '모든',
#  '국민',
#  '언론',
#  '출판',
#  '자유',
#  '집회',
#  '결사',
#  '자유',
#  '언론',
#  '출판',
#  '허',
#  '검열',
#  '집회',
#  '결사',
#  '허가',
#  '인정',
#  '통신',
#  '방송',
#  '시설',
#  '기준',
#  '신문',
#  '기능',
#  '보장',
#  '필요',
#  '사항',
#  '법률',
#  '언론',
#  '출판',
#  '타인',
#  '명예',
#  '권리',
#  '공중',
#  '도덕',
#  '사회',
#  '윤리',
#  '침해',
#  '언론',
#  '출판',
#  '타인',
#  '명예',
#  '권리',
#  '침해',
#  '때',
#  '피해자',
#  '대',
#  '피해',
#  '배상',
#  '청구',
#  '수',
#  '모든',
#  '국민',
#  '학문',
#  '예술',
#  '자유',
#  '저작자',
#  '발명가',
#  '과학',
#  '기술자',
#  '예술가',
#  '권리',
#  '법률',
#  '보호',
#  '모든',
#  '국민',
#  '재산권',
#  '보장',
#  '내용',
#  '한계',
#  '법률',
#  '재산권',
#  '행사',
#  '공공',
#  '복리',
#  '적합',
#  '공공',
#  '필요',
#  '재산권',
#  '수용',
#  '사용',
#  '제한',
#  '보상',
#  '법률',
#  '정',
#  '보상',
#  '지급',
#  '조',
#  '국민',
#  '법률',
#  '바',
#  '선거권',
#  '조',
#  '국민',
#  '법률',
#  '바',
#  '공무',
#  '담임',
#  '모든',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '기관',
#  '문서',
#  '청원',
#  '권리',
#  '국가',
#  '청원',
#  '심사',
#  '의무',
#  '모든',
#  '국민',
#  '헌법',
#  '법률',
#  '법관',
#  '법률',
#  '재판',
#  '권리',
#  '군인',
#  '군무원',
#  '국민',
#  '대한민국',
#  '영역',
#  '안',
#  '중대',
#  '군',
#  '사상',
#  '기밀',
#  '초병',
#  '초소',
#  '음식물',
#  '공급',
#  '포로',
#  '군용물',
#  '죄',
#  '중',
#  '법률',
#  '경우',
#  '비상계엄',
#  '선포',
#  '경우',
#  '제외',
#  '군사',
#  '법원',
#  '재판',
#  '모든',
#  '국민',
#  '신속',
#  '재판',
#  '권리',
#  '형사',
#  '피고인',
#  '상당',
#  '이유',
#  '한',
#  '지체',
#  '공개',
#  '재판',
#  '권리',
#  '형사',
#  '피고인',
#  '유죄',
#  '판결',
#  '확정',
#  '때',
#  '무죄',
#  '추정',
#  '형사',
#  '피해자',
#  '법률',
#  '바',
#  '당해',
#  '사건',
#  '재판',
#  '절차',
#  '진술',
#  '수',
#  '조',
#  '형사',
#  '피의자',
#  '형사',
#  '피고인',
#  '구금',
#  '자가',
#  '법률',
#  '불기소',
#  '처분',
#  '무죄',
#  '판결',
#  '때',
#  '법률',
#  '바',
#  '국가',
#  '정',
#  '보상',
#  '청구',
#  '수',
#  '공무원',
#  '직무',
#  '불법',
#  '행위',
#  '손해',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '공공',
#  '단체',
#  '정',
#  '배상',
#  '청구',
#  '수',
#  '경우',
#  '공무원',
#  '자신',
#  '책임',
#  '면제',
#  '군인',
#  '군무원',
#  '경찰',
#  '공무원',
#  '기타',
#  '법률',
#  '자가',
#  '전투',
#  '훈련',
#  '등',
#  '직무',
#  '집행',
#  '관련',
#  '손해',
#  '법률',
#  '보상',
#  '외',
#  '국가',
#  '공공',
#  '단체',
#  '공무원',
#  '직무',
#  '불법',
#  '행위',
#  '배상',
#  '청구',
#  '수',
#  '조',
#  '타인',
#  '범죄',
#  '행위',
#  '생명',
#  '신체',
#  '피해',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '구조',
#  '수',
#  '모든',
#  '국민',
#  '능력',
#  '균등',
#  '교육',
#  '권리',
#  '모든',
#  '국민',
#  '보호',
#  '자녀',
#  '초등',
#  '교육',
#  '법률',
#  '교육',
#  '의무',
#  '의무',
#  '교육',
#  '무상',
#  '교육',
#  '자주성',
#  '전문',
#  '정치적',
#  '중립성',
#  '대학',
#  '자율성',
#  '법률',
#  '바',
#  '보장',
#  '국가',
#  '평생',
#  '교육',
#  '진흥',
#  '학교',
#  '교육',
#  '평생',
#  '교육',
#  '포함',
#  '교육',
#  '제도',
#  '운영',
#  '교육',
#  '재정',
#  '교원',
#  '지위',
#  '기본',
#  '적인',
#  '사항',
#  '법률',
#  '모든',
#  '국민',
#  '근로',
#  '권리',
#  '국가',
#  '사회적',
#  '경제적',
#  '방법',
#  '근로자',
#  '고용',
#  '증진',
#  '적정',
#  '임금',
#  '보장',
#  '노력',
#  '법률',
#  '바',
#  '최저',
#  '임금제',
#  '시행',
#  '모든',
#  '국민',
#  '근로',
#  '의무',
#  '국가',
#  '근로',
#  '의무',
#  '내용',
#  '조건',
#  '민주',
#  '주의',
#  '원칙',
#  '법률',
#  '근로',
#  '조건',
#  '기준',
#  '인간',
#  '존엄성',
#  '보장',
#  '법률',
#  '여자',
#  '근로',
#  '특별',
#  '보호',
#  '고용',
#  '임금',
#  '근로',
#  '조건',
#  '부당',
#  '차별',
#  '연소자',
#  '근로',
#  '특별',
#  '보호',
#  '국가',
#  '유공자',
#  '상이',
#  '군경',
#  '전몰',
#  '군경',
#  '유가족',
#  '법률',
#  '바',
#  '우선적',
#  '근로',
#  '기회',
#  '근로자',
#  '근로',
#  '조건',
#  '향상',
#  '자주적',
#  '단결권',
#  '단체',
#  '교섭권',
#  '단체',
#  '행동권',
#  '공무원',
#  '근로자',
#  '법률',
#  '자',
#  '단결권',
#  '단체',
#  '교섭권',
#  '단체',
#  '행동권',
#  '법률',
#  '주요',
#  '방위',
#  '산업체',
#  '종사',
#  '근로자',
#  '단체',
#  '행동권',
#  '법률',
#  '바',
#  '제한',
#  '인정',
#  '수',
#  '모든',
#  '국민',
#  '인간',
#  '생활',
#  '권리',
#  '국가',
#  '사회',
#  '보장',
#  '사회',
#  '복지',
#  '증진',
#  '노력',
#  '의무',
#  '국가',
#  '여자',
#  '복지',
#  '권익',
#  '향상',
#  '노력',
#  '국가',
#  '노인과',
#  '청소년',
#  '복',
#  '지향',
#  '정책',
#  '실시',
#  '의무',
#  '신체',
#  '장애자',
#  '질병',
#  '노령',
#  '기타',
#  '사유',
#  '생활',
#  '능력',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '보호',
#  '국가',
#  '재해',
#  '예방',
#  '위험',
#  '국민',
#  '보호',
#  '노력',
#  '모든',
#  '국민',
#  '건강',
#  '환경',
#  '생활',
#  '권리',
#  '국가',
#  '국민',
#  '환경',
#  '보전',
#  '노력',
#  '환경권',
#  '내용',
#  '행사',
#  '법률',
#  '국가',
#  '주택',
#  '개발',
#  '정책',
#  '등',
#  '국민',
#  '주거',
#  '생활',
#  '수',
#  '노력',
#  '혼인',
#  '가족',
#  '생활',
#  '개인',
#  '존엄',
#  '양성',
#  '평등',
#  '기초',
#  '성립',
#  '유지',
#  '국가',
#  '보장',
#  '국가',
#  '모성',
#  '보호',
#  '노력',
#  '모든',
#  '국민',
#  '보건',
#  '국가',
#  '보호',
#  '국민',
#  ...]

# %%
from collections import Counter
# collections.Counter는 hashable 객체들을 카운팅해주는 dict타입 서브클래스

# %%
wordCount = Counter(wordList) # 위의 단어 리스트를 카운팅해주는 Counter객체 생성

# %%
wordCount = wordCount.most_common(40) #높은 빈도수를 가지는 최상위 40개의 단어들을 갖고 온다.

# %%
wordCount
# Out:
# [('법률', 121),
#  ('수', 88),
#  ('대통령', 84),
#  ('국가', 73),
#  ('헌법', 69),
#  ('국민', 69),
#  ('조', 58),
#  ('국회', 55),
#  ('때', 55),
#  ('회의', 42),
#  ('바', 37),
#  ('필요', 31),
#  ('위원', 31),
#  ('국무', 30),
#  ('기타', 26),
#  ('선거', 26),
#  ('보장', 24),
#  ('정부', 23),
#  ('사항', 23),
#  ('의원', 23),
#  ('항', 22),
#  ('자유', 21),
#  ('권리', 21),
#  ('국', 21),
#  ('모든', 21),
#  ('의무', 20),
#  ('제', 20),
#  ('일', 19),
#  ('직무', 19),
#  ('임명', 19),
#  ('경제', 18),
#  ('조직', 18),
#  ('이상', 18),
#  ('국회의원', 18),
#  ('임기', 18),
#  ('공무원', 17),
#  ('경우', 17),
#  ('법원', 17),
#  ('의결', 16),
#  ('단체', 16)]

# %%
import pytagcloud # 태그 클라우드를 만들 수 있게 해주는 라이브러리
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tagList = pytagcloud.make_tags(wordCount, maxsize=40) #태그 리스트를 만든다. size, 색을 알아서 지정해줌.

# %%
pytagcloud.create_tag_image(tagList, "cloud.jpg", fontname="NanumGothic") # 위에서 만들어진 태그 리스트에 대해서 이미지로 저장해준다.

# %% [markdown]
# #### EX) 친구들과의 단톡방 데이터로 어떤 단어가 자주 나왔는지 WordCloud 만들기

# %%
text = open("D:\Study\산학연계\챗봇\데이터셋\가공처리된것\데이터셋1.txt", encoding='utf-8').read()

# %%
text = text.replace('\n','')[3:] # \n들 다 없애줌

# %%
import re

# %%
text_edit = ""
for i in re.findall(r'[가-힣\s]',text):
    text_edit += i

# %%
text_edit
# Out:
# '민방위  교육  스물셋에 민방위라니  넹  개심심  아 드디어    누난 안 가잔아여  노잼일거같아서  상당히  아  아 왜    셤  넌 대구잖아  기간  어  당연하지  언제  아 배고파  까지임  다음주월요일부터  금요일까지  나는그래  다들  그렇겟고만  넌  대구에서뭐하고사냐  개잉여네    코딩이나해    무슨  직장인들이 제일 부러워하는게  이런 소중한시간에  씨언어 한장을  더공부해라  백수임  감기  걸렷다  그럼  누워  서  쉬어야지  쉬어  와 부럽다  아직 복학이 달이나 남았어  와  개부럽다  아 년 더 하고싶다  넌언제복학  학기죠  읭  반학기더한거야  아닌가 작년 여름에했나  보네    아 그때 유럽갔지  크  기억력  늙엇네  그리고  오늘 노잼민방위하면서  신세한탄중이지  무슨  안보교육  글너거함  민방위라는거하면  넹  노잼이네  핵노잼  언제끝남  근데대체  왜 이시간까지그럼  끝나가네요    아살려줘  진짜  다던지고싶다  토탁토닥  담주가중간고사임  이 응  껄껄담주에휴가자들많던데  재밋겟군  유나누나  놋북살때  인터넷으로삼  다른분들은놋북어디서사셨나요  인터넷  주문해서  난  애플 온라인에서  뭐사야될지모르겠다  학생할인받음  호옹  총학에서 할인하는거있어서  맥북삼  그걸로  게다 내 맥북은 터스텀맥북이라  주문제작해서 공장에서 바로나온거임  주문제작    누나가사양선택한거    당연  한걸  램 올리고  끝낫당  씨퓨올림    난아는게없으니걍사야겠다  그냥  가벼운게  장땡    난 주코딩은  뎃탑에서함  그냥 수업필기나하지  놋북으로요즘은  뎃탑아니면 안돌아감 요즘은    고사양임  요즘하는일이  나름대로  나  인터넷으로  주문햇어  다나와  에서  비교해서삿어  네이버에서검색햇엇음  다나와  다나와에서  가격비교가능  대충 견적낼수있음  운영체제  미포함으로  삿어  운영체제 근데 미포함으로 하면  얼마임  내가 깔라고  이면사나  한   정도  아하  싸지는거  같던데  난 정품하나있어서  그거씀    한글파일이랑    도 구해놓고  어디서구함  으아아아아아아아아아아아아아아아아아아악  무게도중요한가보네  꺄아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아  난  그램살까  키로  성범인늘정상이네  짤 삿어  그램  항상  저랬으니까  발열  총견적얼마나왔음  심하다  그래서  와  안삼  그램무겁다  그램이무겁다고  그램   인데  그램개가벼울텐데  키로도안됨    그램이가벼운걸로선전하든데  내 맥북 프로   에어는 인가  그램  인데 케이스끼워서  키로대인듯  난 삼성이티브씀  괜춘함  발열이 심하대  그리고  윈도우  쓰면  아글쿤    돈  내고 써야된대    그래서  윈로  오피스  삼성시리즈도좋을라나  학생공짜아니냐  깔려고 난  요즘 유료인가  학생공짜인데 광운대도될텐데 그거  윈부터 유료라는데  저 잘만씁니다만  삼성아티브쓰는데    가볍긴개가볍구  그게좋음  부팅이짧은게  부팅초  그냥열면켜짐  제컴도  뎃탑도  로긴하고바로뭐할수잇음  부팅이 초입니다  그게굿굿  부팅빠른거처음쓰는데  비싸지  아티브 하지않음  부팅이갑인듯  솔찌기까진괜찮은듯  돈하던거같은데  난 주고  내가알아볼때  삿어  나는  그램이 싸긴하군  에삼  난 돈나와서  그냥 이왕이면  맥북으로  하고 주고 맥북삼  뭐 울트라북이긴하다만  은거아닌가  저정도면  후  뭐사지  레노버도  괜찮던데  이노그램씀  이노한테물어바바  한성 보스몬스터 노트북  보스몬스터  개무겁  아오머리아퍼  인호야그램괜찮음  보스는  겜용이잔항  그램 괜차늠  가볍고 무난함  나도 맥북아니었면  그램샀을듯  그램  랜섬웨어 푸시는 법 아시는 분  헐  그거걸렸어  요즘은잠잠하다던데  일하고 잇는거에 걸렷네    자살각  망함   포맷이답이라든데  시간끌면끝임  돈줘도안풀어주는경우많대  찾아가서 칼빵 놓고싶다  그 복구업체있던데  진심  꽤비싸다그랬던듯  그거  도전 만원  성공하면 만원    실패하면 끝  인생  진심 미치겟다  랜섬웨어가뭐져  먹는건가  랜섬웨어  인질걸림  한강물 뜨시냐  오늘 촤고기온도래  따시다 들어가    뭐하다가걸렷냐  돈주면풀리는거임  셤 끝나고 성범이랑 가면 되냐  인질은무사한가  몰라  디자인팀서 걸림  빼에에에엑  나 저번에 자전거 타고 서울숲갓다옴  시간 걸리드라  하 인생  구웃    크  랜섬이  걸리는구나  랜섬웨어 골치아프지  나도 걸리고 파일 다날라감  아  심심하당  무도한다  비온다  주륵주륵  이젠 니가 채점하네  오잉  뭘채점해  고딩들 시험이나 퀴즈  애들한테 비를 내려  어휴  뭐요  재미있겠다  볼링 몇 치냐  나요  네 너요    그이상 안됨  비슷허네  비가 주룩주룩 내리네  아  아직 볼링 수업있겠지 학교에  잇자 않냐  당구는 없냐  교수랑 맞담하면서 배움 꿀잼일 듯   교수랑  짜장면 내기  꿀쟁  개꿀  당구치고 싶네  서켠이가  언제  나소지  이방은  안죽었네  오지  휴학생들로    겜공시험공부하면서  멘붕중    취중코딩    결국  키로짜리  삿다  뭔취중이여  금주중임     뭐삼  저번에  본거  놋북은  적절히 가볍고 잘돌아가는게짱이징  점심이가일부터나온댓나  헷갈림하도많이나오니  점심이는 언제제대함  월인가    어휴  토나온다  노답  깔깔  심심   비오는  달밤에  밖을 떠돌고잇다    알바언제부터  담주월욜  담주 주말에  서울올라갈까  애들도  다 휴가인거 같던데  담주주말 오오  난여행  담주면시험이끝나지   토욜저녁에옴깔깔  주말에오셈  일욜각이다    장씨랑 왕씨 휴가 언제여  동규야  토욜 저녁 늦게옴  시에신도림도착예정  차렌트반납이신도림임  킬러 오    킬러 조형기  킬러조  셤들 잘봥  성버미이노오진이유나언니셤잘봐랏  올   그랭 후후  내맘대로됫으면조켓다   헐  낼부터셤  시간개빠르다  개월뒤면 복학이야    아직달남았다  벌써 시험기간이라니  나도 달 남았구나  복학하기싫다  졸업하면 실업자  다들 셤때메 바쁘네  아  왜이리 공부할게많냐  으아아아아아아  역대급 빡셈이다  포기하면편해 후후  안됨  이과목은  잘봐야함  이걸 잘 공부하면 실습도   하으  얻어가는 과목이라  다귀차나    난셤만잘보면되  심전실과 겜공 심전실과 컴그는  그따위껀필요없다구  끄앙  과제를 공유하지  매우 꿀  성범이개양아치야  지난학기에도 과제공유로 매우 재미를 봤음  디논하나도모르겠다면서오늘하스생방관전감  어휴    어휴  어쩔수없엇어  디논의늪에빠지느니  하스의늪에  망했어  괜차나    이렇게좀 해봐라  나에겐내일이잇찌  뭐지그냥필기같은데  미리  오늘 공부한건데요  용산갓음    상암스타디움감  완전쌔삥건물  그나저나 오늘 적은건데요  곧한강도가겟네  그래그래 필기  한강    필기를  보여줘  그렇지 한강물요새따뜻한가  따시겟다  내 폭풍필기를  저게필기지  아닌데아닌데  헐  개쩖  누나저거뭔과목  겜공인데  컴소인이면들어야하는건가설마  필기 글씨를 씀 강의 강연 연설 따위의 내용을 받아 적음  이게 필기임    음  그건낙서같은데     복잡해서  알아봄  못알아보겟다  그래서난하지않지  와보기만해도  어차피 흐름은 다 알기때문에  정리는 가능  그러나 시험은 멸망각    그래픽스들을생각있는분없나 혹시  여긴없나  알촌 이름바꿨네  알가로  중 간 고 사   공부집중도와주는글모음    수능금지곡  선곡하지마시구요  올해도 수능날 링딩통 틀어두고 고등학교 배회해야징  못됬네    나만  아니면  되  태욱이형은 자취 학교 근처인가용  아직  안구햇어      지금  방 보고있는데 죄다 월세라  슬프네  월 말 되야 방 풀릴듯  석관동 두산아파트 추천한다  아파트전세 비싸  우리 집값임  기둥  읍읍  이전에 썼던 집  곰팡이만 아니면 쓰는건데 하  돌곶이역이나 월계역쪽도 찾아봥  오홍    고마워 너무 가까운건 싫어서  월계는 버스 잇고 돌곶이는 자전거  자전거 괜춘한데  난 자전거타고 다니잔  책은  사물함 신청해서 넣어야 겠다  통학은  아무리 생각해도 노답인듯  그거 학기에 신청가능하냐  안됨 내꺼써 인용인데 나 혼자 쓰고 잇당    우리 소모임 사물함도 놀고있을거 뻔해서      신형  ...

# %%
word_list = [k for (k,v) in kkma.pos(text_edit) if v.startswith("NN")]

# %%
for i in word_list:
    if len(i) == 1:
        word_list.remove(i)
word_list
# Out:
# ['민방위',
#  '교육',
#  '민방위',
#  '라니',
#  '개심',
#  '기간',
#  '다음주',
#  '월요일',
#  '금요일',
#  '대구',
#  '잉여',
#  '코딩',
#  '직장인',
#  '시간',
#  '언어',
#  '공부',
#  '수임',
#  '감기',
#  '복학',
#  '복학',
#  '학기',
#  '작년',
#  '여름',
#  '그때',
#  '유럽',
#  '오늘',
#  '민방위',
#  '신세',
#  '한탄',
#  '안보',
#  '교육',
#  '거함',
#  '민방위',
#  '하면',
#  '시간',
#  '주가',
#  '간고',
#  '사임',
#  '휴가',
#  '유나',
#  '누나',
#  '인터넷',
#  '인터넷',
#  '주문',
#  '애플',
#  '온라인',
#  '학생',
#  '할인',
#  '할인',
#  '북삼',
#  '게다',
#  '주문',
#  '제작',
#  '공장',
#  '주문',
#  '제작',
#  '누나',
#  '사양',
#  '선택',
#  '올리고',
#  '올림',
#  '사야',
#  '장땡',
#  '코딩',
#  '수업',
#  '필기',
#  '요즘',
#  '요즘',
#  '고사',
#  '요즘',
#  '나름',
#  '인터넷',
#  '주문',
#  '다나',
#  '비교',
#  '네이버',
#  '검색',
#  '다나',
#  '다나',
#  '가격',
#  '비교',
#  '가능',
#  '대충',
#  '견적',
#  '있음',
#  '운영',
#  '체제',
#  '포함',
#  '운영',
#  '체제',
#  '포함',
#  '얼마',
#  '내가',
#  '이면사',
#  '정도',
#  '정품',
#  '파일',
#  '구함',
#  '아악',
#  '무게',
#  '중요',
#  '가보',
#  '그램',
#  '범인',
#  '정상',
#  '그램',
#  '발열',
#  '견적',
#  '얼마',
#  '그램',
#  '그램',
#  '그램',
#  '그램',
#  '개가',
#  '안됨',
#  '그램',
#  '선전',
#  '프로',
#  '에어',
#  '인가',
#  '그램',
#  '케이스',
#  '삼성',
#  '발열',
#  '하대',
#  '윈도',
#  '내고',
#  '오피스',
#  '삼성',
#  '시리즈',
#  '학생',
#  '공짜',
#  '요즘',
#  '유료',
#  '학생',
#  '공짜',
#  '광운',
#  '대도',
#  '유료',
#  '잘만',
#  '삼성',
#  '부팅',
#  '부팅',
#  '켜짐',
#  '부팅',
#  '부팅',
#  '처음',
#  '부팅',
#  '주고',
#  '내가',
#  '그램',
#  '북삼',
#  '울트라',
#  '하다',
#  '은거',
#  '정도',
#  '그램',
#  '한성',
#  '보스',
#  '몬스터',
#  '노트북',
#  '보스',
#  '몬스터',
#  '무겁',
#  '머리',
#  '인호',
#  '그램',
#  '보스',
#  '그램',
#  '난함',
#  '나도',
#  '북아',
#  '그램',
#  '그램',
#  '웨어',
#  '푸시',
#  '아시',
#  '요즘',
#  '자살',
#  '포맷',
#  '시간',
#  '경우',
#  '복구',
#  '업체',
#  '진심',
#  '도전',
#  '만원',
#  '성공',
#  '만원',
#  '실패',
#  '인생',
#  '진심',
#  '웨어',
#  '웨어',
#  '인질',
#  '한강물',
#  '기온',
#  '도래',
#  '주면',
#  '성범',
#  '가면',
#  '인질',
#  '무사',
#  '디자인',
#  '저번',
#  '자전거',
#  '서울',
#  '시간',
#  '걸리',
#  '인생',
#  '웨어',
#  '골치',
#  '나도',
#  '파일',
#  '무도',
#  '이젠',
#  '채점',
#  '무엇',
#  '채점',
#  '시험',
#  '퀴즈',
#  '볼링',
#  '이상',
#  '안됨',
#  '볼링',
#  '수업',
#  '학교',
#  '당구',
#  '교수',
#  '맞담',
#  '수랑',
#  '짜장면',
#  '내기',
#  '개꿀',
#  '당구',
#  '소지',
#  '이방',
#  '휴학',
#  '시험',
#  '공부',
#  '취중',
#  '코딩',
#  '결국',
#  '취중',
#  '금주',
#  '중임',
#  '저번',
#  '본거',
#  '점심',
#  '가일',
#  '심이',
#  '제대',
#  '달밤',
#  '알바',
#  '월욜',
#  '주말',
#  '서울',
#  '휴가',
#  '주주',
#  '여행',
#  '주면',
#  '시험',
#  '토욜',
#  '저녁',
#  '주말',
#  '일욜',
#  '휴가',
#  '토욜',
#  '저녁',
#  '도림',
#  '도착',
#  '예정',
#  '렌트',
#  '반납',
#  '도림',
#  '킬러',
#  '킬러',
#  '조형기',
#  '킬러',
#  '오진',
#  '유나',
#  '언니',
#  '시간',
#  '개월',
#  '복학',
#  '시험',
#  '기간',
#  '복학',
#  '졸업',
#  '실업자',
#  '공부',
#  '역대',
#  '포기',
#  '안됨',
#  '과목',
#  '공부',
#  '실습',
#  '과목',
#  '심전',
#  '실과',
#  '심전',
#  '실과',
#  '과제',
#  '공유',
#  '성범',
#  '양아치',
#  '학기',
#  '과제',
#  '공유',
#  '재미',
#  '오늘',
#  '하스',
#  '방관',
#  '전감',
#  '하스',
#  '내일',
#  '무엇',
#  '필기',
#  '오늘',
#  '공부',
#  '스타디움',
#  '완전',
#  '건물',
#  '한강',
#  '필기',
#  '한강',
#  '필기',
#  '한강물',
#  '폭풍',
#  '필기',
#  '기지',
#  '누나',
#  '과목',
#  '소인',
#  '가설',
#  '필기',
#  '글씨',
#  '강의',
#  '강연',
#  '연설',
#  '따위',
#  '내용',
#  '필기',
#  '낙서',
#  '복잡',
#  '흐름',
#  '때문',
#  '정리',
#  '가능',
#  '시험',
#  '멸망',
#  '그래픽스',
#  '생각',
#  '이름',
#  '가로',
#  '공부',
#  '집중',
#  '모음',
#  '수능',
#  '금지',
#  '선곡',
#  '올해',
#  '수능',
#  '두고',
#  '고등학교',
#  '배회',
#  '이형',
#  '자취',
#  '학교',
#  '근처',
#  '안구',
#  '세라',
#  '석관동',
#  '아파트',
#  '추천',
#  '아파트',
#  '전세',
#  '집값',
#  '기둥',
#  '이전',
#  '곰팡이',
#  '월계',
#  '월계',
#  '버스',
#  '자전거',
#  '자전거',
#  '춘한',
#  '자전거',
#  '사물함',
#  '신청',
#  '통학',
#  '생각',
#  '학기',
#  '신청',
#  '가능',
#  '안됨',
#  '인용',
#  '혼자',
#  '모임',
#  '사물함',
#  '신형',
#  '빌딩',
#  '주가',
#  '예약',
#  '보통',
#  '장수',
#  '단타',
#  '공부',
#  '무음',
#  '알람',
#  '마음',
#  '압정',
#  '장수',
#  '천재',
#  '알람',
#  '요크셔',
#  '테리어',
#  '정도',
#  '사촌',
#  '동생',
#  '장수',
#  '계시',
#  '거의',
#  '초등',
#  '학교',
#  '저학년',
#  '장수장',
#  '수하',
#  '소환',
#  '성공',
#  '주말',
#  '일욜',
#  '생각',
#  '안됨',
#  '서로',
#  '의견',
#  '존중',
#  '이익',
#  '이익',
#  '토요일',
#  '토욜',
#  '일욜',
#  '이안',
#  '고민',
#  '이번',
#  '주말',
#  '왕장',
#  '아늠',
#  '오늘',
#  '누년',
#  '공군',
#  '친구',
#  '공군',
#  '붙음',
#  '호선',
#  '급행',
#  '의미',
#  '의경',
#  '재수',
#  '누보',
#  '공무원',
#  '준비',
#  '사람',
#  '포기',
#  '미련',
#  '토욜',
#  '토욜',
#  '죽여',
#  '희망',
#  '이번',
#  '토요일',
#  '지용',
#  '주말',
#  '게임',
#  '공학',
#  '제곱',
#  '토요일',
#  '토요일',
#  '절대',
#  '평가',
#  '토요일',
#  '토욜',
#  '장소',
#  '잠실',
#  '잠실',
#  '대나',
#  '종각',
#  '대의',
#  '종각',
#  '대가자',
#  '석천',
#  '가게',
#  '지금',
#  '할인',
#  '사람',
#  '니은',
#  '이태원',
#  '고하',
#  '종우',
#  '전역',
#  '이구',
#  '이구',
#  '출면',
#  '외박',
#  '전역',
#  '종우',
#  '다가',
#  '오늘',
#  '부활',
#  '전역',
#  '월전',
#  '역임',
#  '학교',
#  '인쇄소',
#  '라면',
#  '검색',
#  '비마',
#  '광운',
#  '인쇄소',
#  '인쇄',
#  '교가',
#  '롯데',
#  '월드',
#  '롯데',
#  '월드',
#  '롯데',
#  '월드',
#  '그때',
#  '어멈',
#  '학교',
#  '점심',
#  '사람',
#  '프린트',
#  '점심',
#  '유나',
#  '누나',
#  '섭외',
#  '유나',
#  '언니',
#  '소환',
#  '요즘',
#  '라이',
#  '유행',
#  '강의',
#  '교수님',
#  '수업',
#  '강연',
#  '자가',
#  '러시아',
#  '인임',
#  '기절',
#  '수업',
#  '지금',
#  '학교',
#  '세종',
#  '대임',
#  '학교면',
#  '어감',
#  '커피',
#  '이번',
#  '안됨',
#  '과제',
#  '사망',
#  '전임',
#  '내일',
#  '평일',
#  '학교',
#  '주말',
#  '돌이',
#  '과제',
#  '개고',
#  '지옥',
#  '졸작',
#  '여름',
#  '방학',
#  '학교',
#  '지네',
#  '대지',
#  '자대',
#  '인증',
#  '부대',
#  '있음',
#  '게다',
#  '엑스',
#  '대여',
#  '생활',
#  '배터리',
#  '데이터',
#  '배터리',
#  '데이터',
#  '어제',
#  '새벽',
#  '명이',
#  '곡성',
#  '새벽',
#  '종우',
#  '다종',
#  '이형',
#  '근처',
#  '살인',
#  '사건',
#  '미안',
#  '이방인',
#  '초대',
#  '이방',
#  '초대',
#  '용주',
#  '곡성',
#  '느낌',
#  '거보',
#  '생각',
#  '있음',
#  '떡밥',
#  '회수',
#  '이해',
#  '느낌',
#  '구래',
#  '선아',
#  '막걸리',
#  '막걸리',
#  '대야',
#  '한사',
#  '바리',
#  '취한',
#  '기억',
#  '대화방',
#  '정화',
#  '수원시',
#  '영통',
#  '매탄동',
#  '한국',
#  '차아',
#  '파크',
#  '동호',
#  '나기',
#  '대왕',
#  '토토',
#  '요즘',
#  '신경',
#  '사랑',
#  '부대',
#  '내신',
#  '보호',
#  '눈칫밥',
#  '잘못',
#  '시비',
#  '지우개',
#  '아이',
#  '선아',
#  '오른쪽',
#  '연애질',
#  '문제지',
#  '솔로',
#  '발악',
#  '석현',
#  '이형',
#  '게이',
#  '인기',
#  '검색어',
#  '자수',
#  '다행',
#  '전기',
#  '충격',
#  '조심',
#  '도둑',
#  '조심',
#  '내일',
#  '예비군',
#  '조기',
#  '시바',
#  '조기',
#  '자유시간',
#  '군대',
#  '내일',
#  '예비군',
#  '준비',
#  '지금',
#  '군대',
#  '석현',
#  '오빠',
#  '종우',
#  '식이',
#  '전역',
#  '중식',
#  '중식',
#  '병장',
#  '각하',
#  '월중',
#  '중순',
#  '이생',
#  '이생',
#  '나머지',
#  '전역',
#  '군복',
#  '지진',
#  '요즘',
#  '출타',
#  '학회',
#  '도봉산',
#  '선아',
#  '주말',
#  '안됨',
#  '그날',
#  '생일',
#  '이구',
#  '큰일',
#  '마심',
#  '수고',
#  '이랑',
#  '상관',
#  '생일',
#  '주주',
#  '사양',
#  '본거',
#  '풀이',
#  '고고',
#  '이랑',
#  '언니',
#  '이틀',
#  '차이',
#  '합동',
#  '생일',
#  '파티',
#  '고고',
#  '에스',
#  '추가',
#  '제출',
#  '코딩',
#  '과제',
#  '그래픽스',
#  '심취',
#  '에스',
#  '뒷전',
#  '일임',
#  '약속',
#  '토욜',
#  '돌이',
#  '평일',
#  '저녁',
#  '가능',
#  '예비군',
#  '학생',
#  '예비군',
#  '동원',
#  '예비군',
#  '보통',
#  '중간',
#  '휴학',
#  '예비',
#  '군가',
#  '대항해',
#  '시대',
#  '해킹',
#  '복구',
#  '행복',
#  '인호',
#  '학생',
#  '예비군',
#  '신청',
#  '복학',
#  '하면',
#  '복학',
#  '신청',
#  '확인',
#  '신청',
#  '있음',
#  '복학',
#  '이후',
#  '올해',
#  '대면',
#  '내년',
#  '예비군',
#  '올해',
#  '제대',
#  '올해',
#  '올해',
#  '이득',
#  '고고',
#  '지금',
#  '유나',
#  '언니',
#  '바람막이',
#  '민간인',
#  '깔깔이',
#  '군복',
#  '셔츠',
#  '바지',
#  '통일',
#  '남자',
#  '복장',
#  '바지',
#  '바지',
#  '어머님',
#  '진풍경',
#  '옷장',
#  '군복',
#  '사스',
#  '가구',
#  '게임',
#  '시자',
#  '셔츠',
#  '슬랙스',
#  '전투',
#  '위장',
#  '중구난방',
#  '이상',
#  '정도',
#  '드레스',
#  '코드',
#  '내가',
#  '라이',
#  '있음',
#  '검정',
#  '소매',
#  '검정',
#  '감정',
#  '지네',
#  '점수',
#  '현우',
#  '고시',
#  '나의',
#  '경제',
#  '입지',
#  '진이',
#  '의경',
#  '토끼',
#  '과제',
#  '내일',
#  '망월사',
#  '도봉산',
#  '정거장',
#  '경기',
#  '북부',
#  '청사',
#  '학생',
#  '예비군',
#  '의정부',
#  '거가',
#  '학교',
#  '근처',
#  '학생',
#  '예비군',
#  '학교',
#  '훈련장',
#  '교서',
#  '학교',
#  '사격',
#  '학생',
#  '예비군',
#  '수업',
#  '하루',
#  '훈련',
#  '인거',
#  '주변',
#  '휴강',
#  '유나',
#  '누나',
#  '예비군',
#  '아녀',
#  '주변',
#  '라니',
#  '기반',
#  '지각',
#  '호원',
#  '훈련장',
#  '범아',
#  '난개',
#  '이득',
#  '호원',
#  '복도',
#  '리스',
#  '잉여',
#  '차림',
#  '얼굴',
#  '성범',
#  '범아',
#  '종우',
#  '전역',
#  '거지',
#  '브론즈',
#  '브론즈',
#  '장난',
#  '병장',
#  '호봉',
#  '중식',
#  '이월',
#  '전역',
#  '안됨',
#  '이랑',
#  '석현',
#  '오빠',
#  '중식',
#  '종우',
#  '시간',
#  '이랑',
#  '석현',
#  '오빠',
#  '중식',
#  '종우',
#  '시간',
#  '잠시',
#  '얼레',
#  '우가',
#  '시간',
#  '나도',
#  '일본',
#  '군인',
#  '스케줄',
#  '여행',
#  '거하',
#  '범아',
#  '시간',
#  '제한',
#  '엄두',
#  '다음',
#  '주가',
#  '다음',
#  '주가',
#  '일병',
#  '호봉',
#  '제초',
#  '일병',
#  '저번',
#  '휴가',
#  '일병',
#  '상병',
#  '어제',
#  '오늘',
#  '내일',
#  '일병',
#  '범아',
#  '예비군',
#  '잉어',
#  '인호',
#  '오진',
#  '잉여',
#  '진심',
#  '잉여',
#  '잉여',
#  '잉여',
#  '인줄',
#  '소풍',
#  '느낌',
#  '군복',
#  '소풍',
#  '서보',
#  '내보',
#  '비밀',
#  '리스',
#  '소만',
#  '어제',
#  '예비군',
#  '시즌',
#  '학생',
#  '예비군',
#  '시즌',
#  '복학',
#  '신청',
#  '시즌',
#  '방학',
#  '월일',
#  '복학생',
#  '성범',
#  '복학생',
#  '복학생',
#  '이랑',
#  '동기',
#  '졸업',
#  '졸업생',
#  '동기',
#  '라니',
#  '학번',
#  '학번',
#  '차이',
#  '아보',
#  '기분',
#  '야한',
#  '내가',
#  '느낌',
#  '늙은이',
#  '성범',
#  '동갑',
#  '스프',
#  '늙은이',
#  '늙은이',
#  '내가',
#  '막내',
#  '날짜',
#  '정해',
#  '민간인',
#  '공군',
#  '문제',
#  '중식',
#  '광운',
#  '완공',
#  '공사',
#  '박물관',
#  '전시장',
#  '축제',
#  '월로',
#  ...]

# %%
word_count = Counter(word_list)

# %%
word_count = word_count.most_common(30)

# %%
tag_list = pytagcloud.make_tags(word_count, maxsize=100, minsize=20)

# %%
pytagcloud.create_tag_image(tag_list, "cloud_kakaotalk.jpg", fontname="NanumGothic")

# %% [markdown]
# 한 문서에서의 단어의 빈도수 Term Frequency<br>
# 그리고 해당 단어가 다른 문서에서 얼마나 나왔는지 Document Frequency<br>
# 를 결합한 방식이<br>
# TF-IDF 방식

# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
}

params = {
}

url = "https://media.daum.net/"
resp = requests.get(url, params=params, headers=headers) #해당 주소에 대해서 parameter와 header를 넣어서 request
dom = BeautifulSoup(resp.text, "lxml") # BeautifulSoup을 이용해서 텍스트로 받아온다.
aList = dom.select(".list_headline .tit_g > a") #해당하는 태그 내용을 갖고 온다 (주소를 갖고온다)
links = []
for row in aList:
    links.append(row["href"]) # 주소들을 리스트에 넣어준다.

# daum 뉴스에서의 링크들을 뽑아왔다.

# %%
links
# Out:
# ['http://v.media.daum.net/v/20181028164903850',
#  'http://v.media.daum.net/v/20181028164604773',
#  'http://v.media.daum.net/v/20181028164104633',
#  'http://v.media.daum.net/v/20181028164102632',
#  'http://v.media.daum.net/v/20181028163851574',
#  'http://v.media.daum.net/v/20181028163257414',
#  'http://v.media.daum.net/v/20181028163253411',
#  'http://v.media.daum.net/v/20181028163145387',
#  'http://v.media.daum.net/v/20181028163000336',
#  'http://v.media.daum.net/v/20181028162436248',
#  'http://v.media.daum.net/v/20181028161236972',
#  'http://v.media.daum.net/v/20181028161200956']

# %%
for link in links:
    docid = link[-17:]
    resp = requests.get(link, headers=headers)
    html = BeautifulSoup(resp.text, "lxml")
    content = html.select(".article_view")
    
    with open("D:/Study/BigData/JupyterNotebook/Study/doc/{0}".format(docid), "w", encoding='utf-8') as fp:
        fp.write(content[0].text)
        
# 기사 내용을 갖고와서 로컬에 파일로 저장한다.

# %%
import glob # 경로이름을 찾아주는 모듈
import re # 정규식을 쓸 때 사용하는 모듈

# %%
fileList = glob.glob("D:/Study/BigData/JupyterNotebook/Study/doc/*")
# 해당 path안에 있는 파일의 path를 찾아준다.

# %%
with open(fileList[0], "r", encoding='utf-8') as fp: 
    content = fp.read() # 파일을 읽어들임.
    content = re.sub(r"[\s]{2,}", "", content) #정규식을 이용해서 공백이 2개 이상 붙은 것들을 없애준다.

# %%
import nltk

# %%
for sentence in nltk.sent_tokenize(content):
#     words = nltk.word_tokenize(sentence) # nltk로 단어를 tokenize해준다.
    words = nltk.regexp_tokenize(sentence, r"[0-9ㄱ-ㅎㅏ-ㅣ가-힣]+") # 한글과 숫자에 대해서만 허용한 정규식에 따라 영어를 빼고 tokenize해준다.
#     sentence = re.sub( r"[\s\W]+", "", sentence) # 이 경우 WhiteSpace를 다 없애준다.
#     words = []
    
#     for i in range(len(sentence)):
#         words.append(sentence[i:i+2]) #근처의 2개의 글자를 합쳐서 bigram을 만들어준다.
    for word in words:
        tokens = []
        for i in range(len(word)):
            if i+1 < len(word) :
                tokens.append(word[i:i+2])
        print(tokens)
#         print(word)
#         print(tokens, end = "\n\n")
#     print(sentence)
#     print(words, end = "\n\n") # 토큰화된 단어 리스트를 출력해준다.

# 한 글자씩 인접한 1개 글자와 쌍을 맞춰서 list를 생성했다.
# Out:
# ['바른', '른미', '미래', '래당']
# ['등이']
# ['고발', '발한']
# ['사건', '건의']
# ['피고', '고발', '발인']
# ['신분', '분으', '으로']
# ['경찰', '찰조', '조사', '사를']
# ['하루']
# ['앞둔']
# ['이재', '재명']
# ['경기', '기도', '도지', '지사', '사가']
# ['유명']
# ['로펌', '펌인']
# ['법무', '무법', '법인']
# ['화우']
# ['변호', '호사', '사를']
# ['선임', '임하', '하고']
# ['법리']
# ['검토']
# []
# ['조사']
# ['준비', '비를']
# ['마친']
# ['것으', '으로']
# ['확인', '인됐', '됐다']
# []
# ['지사', '사는']
# ['경찰', '찰조', '조사', '사가']
# ['진행', '행되', '되는']
# ['29', '9일']
# ['하루']
# ['휴가', '가를']
# []
# ['상황', '황으', '으로']
# ['이날']
# ['경기', '기도', '도청', '청으', '으로']
# ['출근', '근하', '하지']
# ['않고']
# ['자택', '택에', '에서']
# ['곧바', '바로']
# ['경기']
# ['분당', '당경', '경찰', '찰서', '서에']
# []
# ['예정', '정이', '이다']
# ['이재', '재명']
# ['경기', '기도', '도지', '지사']
# ['사진']
# ['이한', '한형']
# ['기자']
# ['이지', '지사']
# []
# ['법리', '리검', '검토']
# []
# ['모든']
# ['조사', '사준', '준비']
# ['마쳐']
# ['문제']
# ['없을']
# []
# []
# ['지사', '사가']
# ['변호', '호인', '인으', '으로']
# ['선임', '임한']
# ['화우']
# []
# ['20', '00', '03', '3년']
# ['설립', '립돼']
# ['20', '00', '07']
# ['20', '01', '11', '1년']
# ['퇴직']
# ['검사']
# ['16', '66', '6명']
# ['가운', '운데']
# ['대형', '형로', '로펌', '펌에']
# ['취직', '직한']
# ['46', '6명']
# []
# ['8명', '명이']
# ['소속', '속돼']
# ['있는']
# []
# ['김앤', '앤장']
# ['광장']
# ['등과']
# ['함께']
# ['국내']
# ['5대']
# ['대형', '형로', '로펌', '펌으', '으로']
# ['꼽힌', '힌다']
# []
# ['지사', '사가']
# ['선임', '임한']
# ['변호', '호사', '사는']
# ['판사', '사출', '출신', '신으', '으로']
# ['지방', '방선', '선거']
# ['당시']
# ['이재', '재명']
# ['선거', '거캠', '캠프']
# ['에서']
# ['법률']
# ['자문', '문을']
# ['하는']
# []
# ['인연', '연을']
# ['이어']
# []
# ['것으', '으로']
# ['알려', '려졌', '졌다']
# []
# ['지사', '사가']
# ['판사']
# ['출신']
# ['변호', '호사', '사를']
# ['선임', '임한']
# ['이유', '유는']
# ['법리', '리적']
# ['대응', '응에']
# ['집중', '중하', '하기']
# ['위한']
# ['것으', '으로']
# ['분석', '석된', '된다']
# ['지방', '방선', '선거']
# ['당시']
# []
# ['지사']
# ['선거', '거캠', '캠프', '프의']
# ['법률', '률지', '지원']
# ['단장', '장을']
# ['역임', '임했', '했고']
# ['현재']
# []
# ['지사', '사의']
# ['법률', '률대', '대리', '리인', '인을']
# ['맡고', '고있', '있는']
# ['나승', '승철']
# ['변호', '호사', '사의']
# ['경우']
# ['당초']
# ['29', '9일']
# ['경찰', '찰조', '조사', '사에']
# ['동행', '행할']
# ['것으', '으로']
# ['알려', '려졌', '졌으', '으나']
# []
# ['지사', '사의']
# ['부인']
# ['김혜', '혜경', '경씨', '씨의']
# ['이른', '른바']
# ['혜경', '경궁', '궁김', '김씨']
# ['트위', '위터']
# ['계정', '정주']
# ['의혹']
# ['사건', '건에']
# ['주력', '력할']
# ['예정', '정으', '으로']
# ['이번']
# ['조사', '사에', '에는']
# ['동행', '행하', '하지']
# ['않는', '는다']
# []
# ['지사', '사가']
# ['이번']
# ['경찰']
# ['출석', '석에', '에서']
# ['화우']
# ['소속']
# ['변호', '호사']
# ['1명', '명만', '만을']
# ['대동', '동하', '하고']
# ['출석', '석하', '하지', '지만']
# []
# ['지사']
# ['본인', '인도']
# ['변호', '호사', '사인', '인만', '만큼']
# ['사실', '실상']
# ['2명']
# ['변호', '호사', '사가']
# ['경찰', '찰조', '조사', '사에']
# ['대응', '응하', '하는']
# ['것으', '으로']
# ['봐도']
# ['무방', '방하', '하다', '다는']
# ['것이']
# ['이지', '지사', '사측', '측의']
# ['전언', '언이', '이다']
# []
# ['지사', '사의']
# ['최측', '측근', '근은']
# ['28', '8일']
# ['노컷', '컷뉴', '뉴스', '스의']
# ['관련']
# ['취재', '재에']
# ['변호', '호사', '사이', '이기', '기도']
# []
# []
# ['지사', '사가']
# ['내일']
# ['경찰', '찰에']
# ['화우']
# ['소속']
# ['변호', '호사']
# ['1명', '명만', '만을']
# ['대동', '동해']
# ['조사', '사를']
# ['받으', '으러']
# []
# []
# ['이라', '라며']
# ['조사', '사에', '에서']
# ['법리', '리적']
# ['대응', '응에']
# ['주력', '력할']
# ['예정', '정으', '으로']
# ['관련', '련한']
# ['법리', '리검', '검토']
# ['근거', '거자', '자료']
# []
# ['모든']
# ['준비', '비를']
# ['마쳤', '쳤다']
# []
# ['말했', '했다']
# []
# ['다른']
# ['측근', '근은']
# []
# ['변호', '호사', '사와']
# ['화우']
# ['변호', '호사']
# ['외에', '에도']
# []
# ['다른']
# ['변호', '호사', '사의']
# ['자문', '문을']
# ['받는']
# []
# ['조사', '사준', '준비', '비에']
# ['만전', '전을']
# ['기했', '했다']
# ['여러', '러건', '건이']
# ['있지', '지만']
# ['모두']
# ['법리', '리적', '적으', '으로']
# ['문제', '제가']
# ['되지']
# ['않는', '는다', '다고']
# ['판단', '단하', '하고']
# ['있다']
# []
# ['이번']
# ['조사', '사로']
# ['조속', '속히']
# ['논란', '란을']
# ['종결', '결짓', '짓고']
# ['도정', '정에']
# ['전념', '념할']
# []
# ['있을']
# ['것으', '으로']
# ['기대', '대한', '한다']
# []
# ['밝혔', '혔다']
# ['이재', '재명']
# ['경기', '기도', '도지', '지사']
# ['사진']
# ['윤창', '창원']
# ['기자']
# ['경찰']
# ['법리', '리검', '검토']
# ['중요', '요도']
# []
# ['감안', '안해']
# ['법률', '률전', '전문', '문가']
# ['다수']
# ['투입', '입이']
# ['지사']
# ['조사', '사를']
# ['위한']
# ['경기']
# ['분당', '당경', '경찰', '찰서', '서의']
# ['준비', '비도']
# ['만만', '만치']
# ['않은']
# ['것으', '으로']
# ['알려', '려졌', '졌다']
# []
# ['지사', '사에']
# ['대한']
# ['고발']
# ['사건']
# ['수사', '사가']
# ['본격', '격화']
# []
# ['지난']
# []
# ['13']
# ['지방', '방선', '선거']
# []
# ['20', '0여']
# []
# ['규모', '모의']
# ['공직', '직선', '선거', '거법']
# ['위반']
# ['사건']
# ['수사', '사전', '전단', '단팀', '팀을']
# ['꾸린']
# ['경기']
# ['분당', '당경', '경찰', '찰서', '서는']
# ['해당']
# ['전담', '담팀']
# ['분당', '당서']
# ['소속']
# ['2명']
# ['경기']
# ['남부', '부지', '지역']
# ['다른']
# ['경찰', '찰서']
# ['2곳', '곳에', '에서']
# ['파견', '견된']
# ['2명']
# []
# []
# ['변호', '호사']
# ['자격', '격을']
# ['보유', '유한']
# ['경찰', '찰관']
# ['4명', '명을']
# ['포함']
# ['시켰', '켰다']
# ['자치', '치단', '단체', '체장', '장의']
# ['수사', '사에']
# ['4명', '명의']
# ['변호', '호사']
# ['출신']
# ['경찰', '찰관', '관을']
# ['투입', '입하', '하는']
# ['것은']
# ['이례', '례적', '적이', '이란']
# ['평이']
# ['지배', '배적', '적으', '으로']
# []
# ['지사', '사가']
# ['변호', '호사', '사라', '라는']
# ['점을']
# ['고려', '려했', '했을']
# ['것으', '으로']
# ['풀이', '이된', '된다']
# []
# ['경찰']
# ['역시']
# ['친형']
# ['강제', '제입', '입원']
# ['여배', '배우']
# ['스캔', '캔들']
# ['조폭', '폭연', '연루', '루설']
# []
# ['사건', '건의']
# ['경우']
# ['쟁점', '점이']
# ['다수', '수인']
# ['것을']
# ['감안', '안해']
# []
# ['지사', '사와']
# ['마찬', '찬가', '가지', '지로']
# ['법리', '리검', '검토', '토가']
# ['사실', '실관', '관계']
# ['확인', '인만', '만큼']
# ['중요', '요하', '하다', '다고']
# ['판단']
# ['여러', '러명', '명의']
# ['법률']
# ['전문', '문가']
# ['투입', '입이']
# ['불가', '가피']
# ['했을']
# ['것으', '으로']
# ['보여', '여진', '진다']
# ['한편']
# []
# ['지사', '사는']
# ['경찰']
# ['조사', '사를']
# ['하루']
# ['앞둔']
# ['상황', '황에', '에서']
# []
# ['촛불', '불집', '집회']
# ['2주', '주년', '년이']
# ['되는']
# ['내일']
# ['10', '0시']
# ['저는']
# ['경찰', '찰수', '수사', '사를']
# ['받으', '으러']
# ['분당']
# ['경찰', '찰서', '서에']
# ['갑니', '니다']
# []
# ['트윗', '윗과']
# ['함께']
# ['촛불', '불집', '집회']
# ['당시']
# ['박근', '근혜', '혜하', '하야']
# []
# ['요구', '구하', '하며']
# ['끝까', '까지']
# ['함께']
# ['싸워', '워야']
# ['한다']
# []
# ['발언', '언한']
# ['장면', '면이']
# ['담긴']
# ['유튜', '튜브']
# ['영상', '상을']
# ['링크', '크했', '했다']
# ['이는']
# ['지지', '지자', '자들', '들에', '에게']
# ['조사', '사에']
# ['임하', '하는']
# ['의지', '지를']
# ['우회', '회적', '적으', '으로']
# ['보여', '여준']
# ['것으', '으로']
# ['분석', '석된', '된다']
# []
# ['지사', '사는']
# []
# ['이날']
# ['자신', '신의']
# ['페이', '이스', '스북', '북에', '에는']
# ['경기', '기도']
# ['공공', '공부', '부문']
# ['휴게', '게시', '시설']
# ['관리', '리규', '규정']
# ['표준', '준안']
# ['정책', '책을']
# ['홍보', '보했', '했다']
# []
# ['역시']
# ['흔들', '들림']
# ['없이']
# ['도정', '정을']
# ['수행', '행하', '하고']
# ['있음', '음을']
# ['공무', '무원']
# ['도민']
# ['등에', '에게']
# ['강조', '조하', '하기']
# ['위한']
# ['것으', '으로']
# ['해석', '석된', '된다']
# ['노컷', '컷뉴', '뉴스']
# ['동규']
# ['기자']
# []

# %%
from konlpy.tag import Kkma

# %%
uniqueNouns = []


for sentence in nltk.sent_tokenize(content):
    nouns = []
    for word in nltk.word_tokenize(sentence):
        nouns.extend(Kkma().nouns(word)) # 검색 엔진에서도 명사로서 간단히 검색할 때 검색 성능이 제일 좋다.
        nouns = list(set(nouns)) #unique한 단어들만 가져온다.
    uniqueNouns.extend(nouns)
    uniqueNouns = list(set(uniqueNouns)) # set을 통해서 중복되는 것들 없애준다.
#     print(sentence)
#     print(nouns)
#     print(sentence)
#     print(words)
print(len(uniqueNouns))

# 명사들만 가져오는데 중복을 허용하지 않도록 했다.
# Out:
# 294
