# %% [markdown]
# # Pandas분석

# %% [markdown]
# ## Pandas

# %% [markdown]
# pandas는 DataFrame의 경우 2차원 테이블로서 나타낼 수 있다.
# 한 열은 다 series로 불림.
# index. series, DataFrame은 알고 있을 것.
#
# 딥러닝을 지원하는 프레임워크들이 대부분 리눅스에 대해서 지원이 잘된다.

# %%
import pandas as pd

# %% [markdown]
# pandas에서 indexing, slicing하는 방법은 6가지!!

# %%
df = pd.read_csv('data-netflix.csv')

# %%
type(df[['title']]) # 이렇게 []를 2개로 쓰면 DataFrame객체로 반환
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['title']) # 이렇게 []를 1개로 쓰면 Series객체로 반환된다.
# Out:
# pandas.core.series.Series

# %%
type(df.title) # 이렇게 .으로(attribute방식) 찾을 경우 Series객체가 반환
# Out:
# pandas.core.series.Series

# %%
df[['title']] # 밑에 보면 2차원 테이블 형식의 DataFrame객체로 반환
# Out:
#                                           title
# 0                                  White Chicks
# 1                           Lucky Number Slevin
# 2                                Grey's Anatomy
# 3                                  Prison Break
# 4                         How I Met Your Mother
# 5                                  Supernatural
# 6                                  Breaking Bad
# 7                           The Vampire Diaries
# 8                              The Walking Dead
# 9                           Pretty Little Liars
# 10                             Once Upon a Time
# 11                                     Sherlock
# 12                                   Death Note
# 13                                       Naruto
# 14                                   The Hunter
# 15                        Lottie Dottie Chicken
# 16                                        Arrow
# 17                                 Black Mirror
# 18                                The Originals
# ...

# %%
df['title'] # 1차원 벡터로 구성된 Series객체
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %%
df.title # attribute 방식으로 한개의 column에 대해 접근 시에 Series객체 반환
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %% [markdown]
# DataFrame객체에 접근하는 attribute방식

# %%
df.columns #컬럼명에 공백이 있을 경우 attribute방식으로 접근할 수 없다.
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
df[['title', 'rating']] #이러한 dictionary방식은 2개 이상 불러올 수 있다.
# Out:
#                                           title rating
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df[['rating','title']] #이러한 dictionary방식은 순서를 바꿔서 출력 시킬 수도 있다.(sequence)
# Out:
#     rating                                       title
# 0    PG-13                                White Chicks
# 1        R                         Lucky Number Slevin
# 2    TV-14                              Grey's Anatomy
# 3    TV-14                                Prison Break
# 4    TV-PG                       How I Met Your Mother
# 5    TV-14                                Supernatural
# 6    TV-MA                                Breaking Bad
# 7    TV-14                         The Vampire Diaries
# 8    TV-MA                            The Walking Dead
# 9    TV-14                         Pretty Little Liars
# 10   TV-PG                            Once Upon a Time
# 11   TV-14                                    Sherlock
# 12   TV-14                                  Death Note
# 13   TV-PG                                      Naruto
# 14       R                                  The Hunter
# 15    TV-Y                       Lottie Dottie Chicken
# ...

# %% [markdown]
# 한 열만 뽑을 때 DataFrame방식으로 뽑아오고 싶다면
# list안에 넣어서 dictionary 방식으로 갖고오면 된다.
# ex) df[['title']]

# %% [markdown]
# 다만 **attribute방식**( **ex) df.title** ) 은 2개이상의 값을 동시에 갖고 올 수 없다

# %%
df[0] 
#이러한 방식으로 하면 keyerror가 뜬다. -> dictionary방식에 key로 column명을 넣어주어야한다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-914261817e4f> in <module>()
# ----> 1 df[0]
# ...

# %%
df.loc[0] #loc의 경우 해당 index의 row값을 들고 온다.
# Series객체이다.
# Out:
# title                                                     White Chicks
# rating                                                           PG-13
# ratingLevel          crude and sexual humor, language and some drug...
# ratingDescription                                                   80
# release year                                                      2004
# user rating score                                                   82
# user rating size                                                    80
# Name: 0, dtype: object

# %%
df.loc[[0,3]] # pandas의 경우 여러개의 값을 갖고 오고 싶다면 리스트형식으로 넣어준다.
# DataFrame객체이다.
# Out:
#           title rating                                        ratingLevel  \
# 0  White Chicks  PG-13  crude and sexual humor, language and some drug...
# 3  Prison Break  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    ratingDescription  release year  user rating score  user rating size
# 0                 80          2004               82.0                80
# 3                 90          2008               98.0                80

# %% [markdown]
# row의 경우 loc 함수를 통해서 얻어 올 수 있다.

# %%
df.loc[0:2] # slicing도 지원을 해준다.
# DataFrame객체
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80

# %% [markdown]
# column의 경우 dictionary이기 때문에 slicing, indexing을 지원해주지 않는다.

# %%
df.loc[1:3, 'title'] # title column에 대해서 1~3 인덱스의 row를 갖고 온다.
# Series객체

# df.loc[1:3, ['title']]
# 위처럼 갖고 오고 싶은 컬럼을 리스트에 넣어서 부를 경우 DataFrame객체로 반환
# Out:
# 1    Lucky Number Slevin
# 2         Grey's Anatomy
# 3           Prison Break
# Name: title, dtype: object

# %%
df.loc[1:3, ['title','rating']] # column title, rating에 대해서 1~3 인덱스의 row를 갖고 온다.
# Out:
#                  title rating
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
# 3         Prison Break  TV-14

# %%
df.loc[:] #dictionary방식처럼 갖고온다. 처음부터 끝까지 갖고 온다.
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
type(df.loc[:]) #이렇게 DataFrame객체 이므로, describe, info, head, tail 등을 쓸 수 있다.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# loc의 경우 label기반으로 데이터를 찾는다. __ex) df.loc['title']__
# iloc의 경우 index기반으로 해당 데이터를 찾아준다. __ex) df.iloc[1,1]__

# %%
df.at[1,'rating'] #at은 1개의 row를 갖고 올 때 (indexing을 통해서)
# String형으로 반환
# Out:
# 'R'

# %%
# %timeit df.loc[1,'rating'] #loc의 경우 속도가 좀 느리다.
# Out:
# 9.04 µs ± 845 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit df.at[1,'rating'] #at의 경우 속도가 더 빠르다. 
#한가지의 데이터를 갖고 올 때는 at을 쓰는 것이 더 좋다.
# Out:
# 5.47 µs ± 522 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.at[1,'rating'] = 'R' #이러한 방식으로 데이터를 직접 바꿔 줄 수 있다.

# %% [markdown]
# dictionary, attribute, loc, at방식으로 특정데이터에 접근.

# %%
df.axes # 해당 DataFrame객체의 axes를 알려준다.
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#         'user rating score', 'user rating size'],
#        dtype='object')]

# %% [markdown]
# axes는 다차원 벡터(배열) 등에서의 축을 의미한다.

# %%
df.iat # integer(index)베이스 at 방식

# %%
df.iat[1,1] # row, column 차례로 넣으면 해당 데이터 한개를 갖고옴.
# Out:
# 'R'

# %%
df.at[1, 'title']
# Out:
# 'Lucky Number Slevin'

# %%
df.at[1,1] 
#이것은 label 베이스이기 때문에 row와 column에 대한 index를 넣으면 이렇게 에러가 발생.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6a9848575cb8> in <module>()
# ----> 1 df.at[1,1]
#       2 #이것은 label 베이스이기 때문에 row와 column에 대한 index를 넣으면 이렇게 에러가 발생.
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2139                 raise ValueError('Invalid call for scalar access (getting)!')
#    2140
# -> 2141         key = self._convert_key(key)
#    2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2225             else:
#    2226                 if is_integer(i):
# -> 2227                     raise ValueError("At based indexing on an non-integer "
#    2228                                      "index can only have non-integer "
# ...

# %% [markdown]
# iat은 우리 눈에 편하게 불러올수 있도록 변환단계가 한개가 더 있다. 시간이 더 걸리긴하지만 iat을 더 많이 씀

# %%
# %timeit df.iat[1,1]
# Out:
# 5.81 µs ± 423 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit df.at[1,'title']
# Out:
# 5.22 µs ± 213 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.loc[1:3, 'rating'] # loc의 경우는 dictionary 베이스이기 때문에 1:3에서 3까지 포함된다.
# Out:
# 1        R
# 2    TV-14
# 3    TV-14
# Name: rating, dtype: object

# %%
df.iloc[1:3, 1] # iloc는 index 베이스이기 때문에 slicing, indexing해줄 때 리스트와 같음
# Out:
# 1        R
# 2    TV-14
# Name: rating, dtype: object

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_csv('data-zillow.csv',sep=',') # , 기준으로 데이터를 나눠줌.

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
df.describe()
# Out:
#             RegionID      SizeRank          Zhvi
# count   10830.000000  10830.000000  1.083000e+04
# mean    84344.818837   5414.500000  2.503076e+05
# std    125679.686534   3126.496042  2.565582e+05
# min      3301.000000      0.000000  3.740000e+04
# 25%     19346.250000   2707.250000  1.269000e+05
# 50%     35444.500000   5414.500000  1.818000e+05
# 75%     52608.250000   8121.750000  2.823500e+05
# max    737791.000000  10829.000000  6.343800e+06

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df.tail()
# Out:
#              Date  RegionID         RegionName State     Metro      County  \
# 10825  2017-05-31     26077            Nehalem    OR       NaN   Tillamook
# 10826  2017-05-31     24105  Clear Lake Shores    TX   Houston   Galveston
# 10827  2017-05-31    737788    Lebanon Borough    NJ  New York   Hunterdon
# 10828  2017-05-31    182023            Henrico    VA  Richmond     Henrico
# 10829  2017-05-31     51793     East Hampstead    NH    Boston  Rockingham
#
#        SizeRank    Zhvi
# 10825     10825  392200
# 10826     10826  191900
# 10827     10827  231100
# 10828     10828  230800
# 10829     10829  296400

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
df['RegionName'] # dictionary방식으로 series객체 반환
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
type(df['RegionName'])
# Out:
# pandas.core.series.Series

# %%
df.loc[:,'RegionName']
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.iloc[:,2]
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.count() # 해당 컬럼에 대해서 row의 개수를 알려준다.
# Out:
# Date          10830
# RegionID      10830
# RegionName    10830
# State         10830
# Metro         10256
# County        10830
# SizeRank      10830
# Zhvi          10830
# dtype: int64

# %%
df.mean() # 숫자형 데이터에 대해서 평균을 내준다.
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.std() # default로 N-1으로 정규화되며, 표준 편차를 반환해준다.
# Out:
# RegionID    125679.686534
# SizeRank      3126.496042
# Zhvi        256558.223083
# dtype: float64

# %%
df.skew()
# N-1으로 표준화된 axis에 대하여 편향되지않은(unbiased) 왜도(skew)를 반환해준다.
# Out:
# RegionID    1.973159
# SizeRank    0.000000
# Zhvi        6.714811
# dtype: float64

# %%
df.kurt() # N-1으로 표준화되 axis에 대하여 편향되지않은 첨도(kurtosis)를 반환
# Fisher의 정의를 사용한 첨도
# Out:
# RegionID     2.291461
# SizeRank    -1.200000
# Zhvi        82.042387
# dtype: float64

# %%
df.corr() 
# NA / NULL 값을 제외한 Column들의 쌍별로(pairwise) 상관계수(correlation)를 계산
# Out:
#           RegionID  SizeRank      Zhvi
# RegionID  1.000000  0.052025 -0.032184
# SizeRank  0.052025  1.000000 -0.115621
# Zhvi     -0.032184 -0.115621  1.000000

# %%
df.cov() 
# NA / NULL 값을 제외한 Column들의 쌍별로(pairwise) 공분산(covariance)를 계산
# Out:
#               RegionID      SizeRank          Zhvi
# RegionID  1.579538e+10  2.044245e+07 -1.037760e+09
# SizeRank  2.044245e+07  9.774978e+06 -9.274275e+07
# Zhvi     -1.037760e+09 -9.274275e+07  6.582212e+10

# %% [markdown]
# 왜도(skewness)
# 첨도(kurtosis)
# 상관계수(correlation)
# 공분산(covariance)

# %% [markdown]
# 통계쪽에서는 R, CS쪽에서는 Python을 선호한다.

# %%
df.iloc[:, 1:3] # 1:3 -> 1,2 에 대해서 나옴...
# Out:
#        RegionID         RegionName
# 0          6181           New York
# 1         12447        Los Angeles
# 2         17426            Chicago
# 3         13271       Philadelphia
# 4         40326            Phoenix
# 5         18959          Las Vegas
# 6         54296          San Diego
# 7         38128             Dallas
# 8         33839           San Jose
# 9         25290       Jacksonville
# 10        20330      San Francisco
# 11        10221             Austin
# 12        17762            Detroit
# 13        10920           Columbus
# 14        32811            Memphis
# 15        24043          Charlotte
# 16        17933            El Paso
# 17        44269             Boston
# 18        16037            Seattle
# 19         3523          Baltimore
# 20        11093             Denver
# 21        41568         Washington
# 22         6118          Nashville
# 23         5976          Milwaukee
# 24         7481             Tucson
# 25        13373           Portland
# ...

# %%
df.iat[1,4] = 'Los Angeles Long Beach-Anaheim'
# 2번째(index 1) row의 5번째(index 4) Column(Metro)

# %%
df.at[1,'Metro']
# label 1을 지니는 row의 'Metro'라벨을 지니는 Column
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.iloc[1,4]
# 2번째(index 1) row의 5번째(index 4) Column(Metro)
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.loc[1,'Metro']
# label 1을 지니는 row의 'Metro'라벨을 지니는 Column
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df['Metro'][1]
# df[Column][row] 방식으로 갖고온다.
# 'Metro' Column의 '1' 라벨을 지니는 row
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.Metro[1]
# attribute방식으로 df의 Metro Column의 1 라벨을 지니는 것.
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.loc[7,'Metro':'County'] # 7번째 row의 Metro부터 County까지
# Out:
# Metro     Dallas-Fort Worth
# County               Dallas
# Name: 7, dtype: object

# %%
df.iloc[0:7, 0:3] # 0~6 인덱스의 row, 0~2 인덱스의 column
# Out:
#          Date  RegionID    RegionName
# 0  2017-05-31      6181      New York
# 1  2017-05-31     12447   Los Angeles
# 2  2017-05-31     17426       Chicago
# 3  2017-05-31     13271  Philadelphia
# 4  2017-05-31     40326       Phoenix
# 5  2017-05-31     18959     Las Vegas
# 6  2017-05-31     54296     San Diego

# %%
df['조보아'] = 3 # 새로운 column을 추가해서 모든 값에 대해 3을 준다.

# %%
df #이러한 기법을 broadcasting이라고 한다.
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
del df['조보아'] # Python기반이기 때문에 del을 통해서 해당 데이터를 삭제 할 수 있다.

# %%
df # '조보아' Column이 사라졌음을 볼 수 있다.
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
df.iloc[1,4] # index 1 row, index 3 column
# Out:
# 'Los Angeles Long Beach-Anaheim'

# %%
df.iloc[7, [4,6]] # index 7 row, index 4, 6 column
# Out:
# Metro       Dallas-Fort Worth
# SizeRank                    7
# Name: 7, dtype: object

# %%
df.loc[11,:] # label이 11인 것 row 전체 갖고옴
# Out:
# Date          2017-05-31
# RegionID           10221
# RegionName        Austin
# State                 TX
# Metro             Austin
# County            Travis
# SizeRank              11
# Zhvi              321600
# Name: 11, dtype: object

# %%
df.loc[201:204, ['State','County']]
# Out:
#     State         County
# 201    OH          Stark
# 202    LA      Jefferson
# 203    CA  Santa Barbara
# 204    CA    Los Angeles

# %%
df.iloc[201:205, 3:6]
# Out:
#     State                           Metro         County
# 201    OH                          Canton          Stark
# 202    LA                     New Orleans      Jefferson
# 203    CA       Santa Maria-Santa Barbara  Santa Barbara
# 204    CA  Los Angeles-Long Beach-Anaheim    Los Angeles

# %%
df.loc[df.County=='Queens'] #해당 조건에 맞는 데이터를 갖고옴.
# Out:
#          Date  RegionID RegionName State     Metro  County  SizeRank    Zhvi
# 0  2017-05-31      6181   New York    NY  New York  Queens         0  672400

# %%
df.loc[df.Date == '2017-05-31']
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %% [markdown]
# 특정 행 -> dictionary. attribute -->  설정에 따라 dictionary, attribute를 통해서 특정 열만 가져올 수 있다.
# 특정 열 -> loc, iloc
# 특정 데이터 한개 -> iat, at
#
# iloc의 경우 모두 표현해낼 수 있다...

# %%
df.loc[1:3]
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
#
#          County  SizeRank    Zhvi
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300

# %%
df.iloc[1:3]
# Out:
#          Date  RegionID   RegionName State                           Metro  \
# 1  2017-05-31     12447  Los Angeles    CA  Los Angeles Long Beach-Anaheim
# 2  2017-05-31     17426      Chicago    IL                         Chicago
#
#         County  SizeRank    Zhvi
# 1  Los Angeles         1  629900
# 2         Cook         2  222700

# %%
df.loc[df['State'] == 'CA'] # State가 CA인 모든 row들을 갖고 와라
#loc이기 때문에 label이 들어와야 한다.
# 함수형 paradigm
# Out:
#              Date  RegionID        RegionName State  \
# 1      2017-05-31     12447       Los Angeles    CA
# 6      2017-05-31     54296         San Diego    CA
# 8      2017-05-31     33839          San Jose    CA
# 10     2017-05-31     20330     San Francisco    CA
# 29     2017-05-31     18203            Fresno    CA
# 30     2017-05-31     20288        Sacramento    CA
# 32     2017-05-31     46298        Long Beach    CA
# 38     2017-05-31     13072           Oakland    CA
# 49     2017-05-31     16764           Anaheim    CA
# 50     2017-05-31     47568         Santa Ana    CA
# 55     2017-05-31     47401         Riverside    CA
# 58     2017-05-31      3506       Bakersfield    CA
# 65     2017-05-31      7266          Stockton    CA
# 70     2017-05-31     25934           Modesto    CA
# 83     2017-05-31     20328    San Bernardino    CA
# 84     2017-05-31     24225            Corona    CA
# 85     2017-05-31     51405       Chula Vista    CA
# ...

# %% [markdown]
# filter, map, reduce????? -> 함수형 기법??

# %%
df.loc[df.Metro == 'New York', "County"]
# Metro == 'New York'인 row들 중에서 "County"열만 출력해준다.
# Out:
# 0             Queens
# 63             Essex
# 72            Hudson
# 138      Westchester
# 176          Passaic
# 225            Union
# 291        Middlesex
# 338            Ocean
# 387            Ocean
# 402          Passaic
# 406         Dutchess
# 521      Westchester
# 541            Ocean
# 564          Passaic
# 582           Hudson
# 591            Essex
# 611      Westchester
# 631           Hudson
# 651           Nassau
# 716           Hudson
# 727      Westchester
# 732           Nassau
# 735         Monmouth
# 750            Essex
# 760          Passaic
# 779            Ocean
# 781            Union
# 787        Middlesex
# 800           Orange
# 806        Middlesex
#             ...
# 9591       Hunterdon
# 9614         Suffolk
# 9714         Suffolk
# 9732           Ocean
# 9777           Ocean
# 9791           Ocean
# 9805        Monmouth
# 9817           Ocean
# 9819        Monmouth
# 9820           Ocean
# 9860        Monmouth
# 9939       Hunterdon
# ...

# %% [markdown]
# sorting

# %%
df.sort_values(['RegionID','State'], ascending=[False,True]) # 복수의 값을 넣을 때는 리스트 형식으로 넣는다.
# 'RegionID' 를 기준으로 내림차순 정렬. 만약 RegionID중에 같은 것들이 있다면 'State' 기준으로 오름차순 정렬
# axis = 0 -> 행, axis = 1 -> 열
# inplace == mutable
# Out:
#              Date  RegionID             RegionName State  \
# 1736   2017-05-31    737791      Town of Mansfield    CT
# 731    2017-05-31    737790               Eastvale    CA
# 10827  2017-05-31    737788        Lebanon Borough    NJ
# 413    2017-05-31    737787         San Tan Valley    AZ
# 9295   2017-05-31    737786          The Sea Ranch    CA
# 8209   2017-05-31    399307       Berwick Township    PA
# 3154   2017-05-31    399305       Swatara Township    PA
# 2813   2017-05-31    399300        Exeter Township    PA
# 741    2017-05-31    399297      Muskegon Township    MI
# 10001  2017-05-31    399293                 Covert    NY
# 2971   2017-05-31    399292      Whitpain Township    PA
# 6119   2017-05-31    399290     Sugarloaf Township    PA
# 6475   2017-05-31    399289          Penn Township    PA
# 2124   2017-05-31    399288     Allendale Township    MI
# 6881   2017-05-31    399287    Portsmouth Township    MI
# ...

# %%
df.sort_values('RegionID', inplace=True) 
#inplace를 통해 정렬된 상태로 df를 저장

# %%
df
# Out:
#              Date  RegionID             RegionName State  \
# 3043   2017-05-31      3301               Aberdeen    NC
# 4159   2017-05-31      3304                Absecon    NJ
# 4986   2017-05-31      3305               Accokeek    MD
# 1762   2017-05-31      3310                    Ada    OK
# 3116   2017-05-31      3312            Adairsville    GA
# 10202  2017-05-31      3315                  Adams    TN
# 1136   2017-05-31      3319                Addison    IL
# 10569  2017-05-31      3322                   Addy    WA
# 8018   2017-05-31      3333               Ahwahnee    CA
# 622    2017-05-31      3334                  Aiken    SC
# 3261   2017-05-31      3344                 Albion    MI
# 8315   2017-05-31      3352             Alexandria    AL
# 10456  2017-05-31      3379                   Alta    CA
# 10537  2017-05-31      3403              Andalusia    IL
# 378    2017-05-31      3404               Anderson    SC
# ...

# %%
df.sort_values('RegionID', axis=0)
# Out:
#              Date  RegionID             RegionName State  \
# 3043   2017-05-31      3301               Aberdeen    NC
# 4159   2017-05-31      3304                Absecon    NJ
# 4986   2017-05-31      3305               Accokeek    MD
# 1762   2017-05-31      3310                    Ada    OK
# 3116   2017-05-31      3312            Adairsville    GA
# 10202  2017-05-31      3315                  Adams    TN
# 1136   2017-05-31      3319                Addison    IL
# 10569  2017-05-31      3322                   Addy    WA
# 8018   2017-05-31      3333               Ahwahnee    CA
# 622    2017-05-31      3334                  Aiken    SC
# 3261   2017-05-31      3344                 Albion    MI
# 8315   2017-05-31      3352             Alexandria    AL
# 10456  2017-05-31      3379                   Alta    CA
# 10537  2017-05-31      3403              Andalusia    IL
# 378    2017-05-31      3404               Anderson    SC
# ...

# %%
df.sort_values('RegionID', inplace=True)

# %%
df.reset_index(inplace = True) #과거의 index를 자동으로 column으로 추가 시켜준다.

# %%
df
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
df.reset_index(drop=True) #과거의 index를 없애준다.
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %% [markdown]
# ----

# %% [markdown]
# 정규식이 굉장히 중요하다!!!!!

# %% [markdown]
# 좀전에 df.loc에 condition을 줘서 filtering을 해줬는데 아예 filter라는 메소드가 있다.

# %%
df.filter(items=['State', 'Metro']) #특정한 데이터만 필터링 해주는 것이다.  
# like는 어떤 특정단어를 포함하는지 안 포함하는지
# regex를 통해서 정규식으로 원하는 string을 분류해낼 수 있다. 

#dictionary에 list를 넣은 방식과 동일하게 출력된다.

#현재 'State', 'Metro' Column의 데이터를 필터링해주었다.
# Out:
#       State                           Metro
# 0        NC        Pinehurst-Southern Pines
# 1        NJ                   Atlantic City
# 2        MD                      Washington
# 3        OK                             Ada
# 4        GA                         Atlanta
# 5        TN                     Clarksville
# 6        IL                         Chicago
# 7        WA                         Spokane
# 8        CA                          Madera
# 9        SC                         Augusta
# 10       MI                    Battle Creek
# 11       AL                        Anniston
# 12       CA                      Sacramento
# 13       IL                       Davenport
# 14       SC                      Greenville
# 15       TN                       Knoxville
# 16       IN                          Angola
# 17       AZ                         Phoenix
# 18       FL                           Ocala
# 19       MN             Minneapolis-St Paul
# ...

# %%
filtered_data = df.filter(regex='^Region', axis=1) 
#해당 column명이 Region으로 시작하고, axis=1을 주어서 모든 row를 갖고온다. 
filtered_data.head() # 필터링된 데이터의 head()
# Out:
#    RegionID   RegionName
# 0      3301     Aberdeen
# 1      3304      Absecon
# 2      3305     Accokeek
# 3      3310          Ada
# 4      3312  Adairsville

# %%
df.loc[df['Zhvi'] > 500000] # 'Zhvi'에서 500000이상 값을 가지는 row
# Out:
#        index        Date  RegionID              RegionName State  \
# 27      6714  2017-05-31      3491                  Avalon    CA
# 30      7720  2017-05-31      3509             Bal Harbour    FL
# 48       211  2017-05-31      3619                Bellevue    WA
# 71     10205  2017-05-31      3734             Boca Grande    FL
# 78      1102  2017-05-31      3761                 Bothell    WA
# 87      5016  2017-05-31      3811                   Brier    WA
# 104     5342  2017-05-31      3893                 Burbank    CA
# 108     4637  2017-05-31      3929               Calistoga    CA
# 111      267  2017-05-31      3934               Cambridge    MA
# 117      293  2017-05-31      3975                Carlsbad    CA
# 118     2649  2017-05-31      3980             Carpinteria    CA
# 125     7328  2017-05-31      4028              Centerport    NY
# 144     7385  2017-05-31      4145              Clyde Hill    WA
# ...

# %%
df[df.Zhvi > 1000000] # dic 방식 -> Zhvi에서 1000000 이상을 가지는 row들
# Out:
#        index        Date  RegionID                  RegionName State  \
# 30      7720  2017-05-31      3509                 Bal Harbour    FL
# 71     10205  2017-05-31      3734                 Boca Grande    FL
# 144     7385  2017-05-31      4145                  Clyde Hill    WA
# 173      757  2017-05-31      4281                   Cupertino    CA
# 376     3225  2017-05-31      5415                Key Biscayne    FL
# 585     3417  2017-05-31      6495                    Piedmont    CA
# 642     8728  2017-05-31      6822               Rolling Hills    CA
# 647    10538  2017-05-31      6840                        Ross    CA
# 664     1393  2017-05-31      6916                  San Carlos    CA
# 805     9714  2017-05-31      7774                  Water Mill    NY
# 829     1699  2017-05-31      7892                    Westport    CT
# 903     6443  2017-05-31      8306         Bunker Hill Village    TX
# 944    10808  2017-05-31      8646                   Inverness    CA
# ...

# %%
filtered_data = df.filter(like = 'Metro', axis=1) #like는 포함하는 것....
filtered_data.head()

#filter 또한 column을 뽑아 낼 때 이용할 수 있다. (그외에 dictionary, attribute, loc, iloc)
# Out:
#                       Metro
# 0  Pinehurst-Southern Pines
# 1             Atlantic City
# 2                Washington
# 3                       Ada
# 4                   Atlanta

# %%
df[(df['Zhvi'] > 1000000) & (df['State'] == 'NY')]
# 조건을 추가시 
#  AND -> & 
#  OR -> |
# Out:
#       index        Date  RegionID              RegionName State     Metro  \
# 805    9714  2017-05-31      7774              Water Mill    NY  New York
# 1694   6661  2017-05-31     12894              Muttontown    NY  New York
# 1886   3904  2017-05-31     13937             Southampton    NY  New York
# 2215   8093  2017-05-31     16387             Sands Point    NY  New York
# 2466   6736  2017-05-31     17874              East Hills    NY  New York
# 2557   1132  2017-05-31     18375              Great Neck    NY  New York
# 2572   3474  2017-05-31     18478                Harrison    NY  New York
# 2646   3064  2017-05-31     18955               Larchmont    NY  New York
# 2649   9028  2017-05-31     18963             Lattingtown    NY  New York
# 2794   9055  2017-05-31     19808         Oyster Bay Cove    NY  New York
# 3157   9370  2017-05-31     22015           Laurel Hollow    NY  New York
# 3748   3032  2017-05-31     25725               Manhasset    NY  New York
# ...

# %% [markdown]
# pandas가 excel보다 빠르고 조건도 많이 넣을 수 있어서 전처리하기 좋다

# %%
_filter = df['Metro'].isin(['New York','San Francisco'])
# isin은 in과 동일함  -> Metro Column내에 New York, San Francisco가 있는지 확인

df[df['State'].isin(['DC','PA'])] # 행 필터링의 경우 data[]내에 조건을 넣어준다.
# 'State' Column에서 'DC', 'PA'를 지니고 있는 조건을 지닌 row들을 출력해줌.
# Out:
#        index        Date  RegionID                RegionName State  \
# 20      3101  2017-05-31      3436                   Ardmore    PA
# 25      7440  2017-05-31      3465                    Ashley    PA
# 47      4220  2017-05-31      3618                  Bellevue    PA
# 57      3636  2017-05-31      3649                   Berwick    PA
# 68      2804  2017-05-31      3706                Bloomsburg    PA
# 69      5302  2017-05-31      3711                 Blue Bell    PA
# 90      8237  2017-05-31      3831                  Brockway    PA
# 136     9462  2017-05-31      4106              Clarks Green    PA
# 137     5708  2017-05-31      4107             Clarks Summit    PA
# 205     1653  2017-05-31      4502                    Easton    PA
# 230     6801  2017-05-31      4615                      Etna    PA
# 252     4012  2017-05-31      4727                 Fleetwood    PA
# 256     7178  2017-05-31      4745                 Ford City    PA
# ...

# %%
df.loc[df['State'].isin(['DC','PA'])] #loc를 넣어주어도 똑같은 값이 출력된다.
# Out:
#        index        Date  RegionID                RegionName State  \
# 20      3101  2017-05-31      3436                   Ardmore    PA
# 25      7440  2017-05-31      3465                    Ashley    PA
# 47      4220  2017-05-31      3618                  Bellevue    PA
# 57      3636  2017-05-31      3649                   Berwick    PA
# 68      2804  2017-05-31      3706                Bloomsburg    PA
# 69      5302  2017-05-31      3711                 Blue Bell    PA
# 90      8237  2017-05-31      3831                  Brockway    PA
# 136     9462  2017-05-31      4106              Clarks Green    PA
# 137     5708  2017-05-31      4107             Clarks Summit    PA
# 205     1653  2017-05-31      4502                    Easton    PA
# 230     6801  2017-05-31      4615                      Etna    PA
# 252     4012  2017-05-31      4727                 Fleetwood    PA
# 256     7178  2017-05-31      4745                 Ford City    PA
# ...

# %% [markdown]
# sql에서의 in과 같은 기능을 제공하지만 in이라는 keyword가 이미 존재하므로 isin으로 이름을 지음

# %%
import pandas as pd
df = pd.read_csv('apt_final.csv')
df
# Out:
#         price_per_area     price  con_year  year dong           aptnm  month  \
# 0                 1979   71000.0      1982  2009  개포동        개포주공 3단지     10
# 1                 1994   83700.0      1982  2009  개포동        개포주공 1단지     10
# 2                 1128  173500.0      2004  2009  개포동      개포자이(12-2)     10
# 3                 1204   65000.0      1983  2009  개포동        개포주공 5단지     10
# 4                 1214  160000.0      1986  2009  개포동             현대2     10
# 5                 1480   75000.0      1982  2009  개포동        개포주공 4단지     10
# 6                 1030   82000.0      1987  2009  개포동             우성8     10
# 7                 1275   78000.0      1983  2009  개포동        개포주공 5단지     10
# 8                 1975  100000.0      1982  2009  개포동        개포주공 1단지     10
# 9                 1133   44800.0      1992  2009  개포동      성원대치2단지아파트     10
# 10                1115   37000.0      1992  2009  개포동      성원대치2단지아파트     10
# ...

# %%
dong_list =["역삼동", "개포동", "청담동", "삼성동", "대치동", "신사동", "논현동", "압구정동", "세곡동", "자곡동", "율현동", "일원동", "수서동", "도곡동", "논현1동", "논현2동", "삼성1동", "삼성2동", "대치1동", "대치2동", "대치4동", "역삼1동", "역삼2동", "도곡1동", "도곡2동", "개포1동", "개포2동", "개포4동", "일원본동", "일원1동", "일원2동"]

# %%
df.loc[df['dong'].isin(dong_list)]
# 강남구에 포함된 동들만 list로 갖고 와서 강남구에 대한 정보만 뽑아왔다.
# Out:
#         price_per_area     price  con_year  year dong           aptnm  month  \
# 0                 1979   71000.0      1982  2009  개포동        개포주공 3단지     10
# 1                 1994   83700.0      1982  2009  개포동        개포주공 1단지     10
# 2                 1128  173500.0      2004  2009  개포동      개포자이(12-2)     10
# 3                 1204   65000.0      1983  2009  개포동        개포주공 5단지     10
# 4                 1214  160000.0      1986  2009  개포동             현대2     10
# 5                 1480   75000.0      1982  2009  개포동        개포주공 4단지     10
# 6                 1030   82000.0      1987  2009  개포동             우성8     10
# 7                 1275   78000.0      1983  2009  개포동        개포주공 5단지     10
# 8                 1975  100000.0      1982  2009  개포동        개포주공 1단지     10
# 9                 1133   44800.0      1992  2009  개포동      성원대치2단지아파트     10
# 10                1115   37000.0      1992  2009  개포동      성원대치2단지아파트     10
# ...

# %%
df['gu'] = "" # 'gu'라는 column 생성

# %%
df['dong'].isin(dong_list) # dong에 해당 리스트내의 동이 있는지 확인
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True
# 13         True
# 14         True
# 15         True
# 16         True
# 17         True
# 18         True
# 19         True
# 20         True
# 21         True
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29         True
#           ...
# 429436    False
# 429437    False
# 429438    False
# 429439    False
# 429440    False
# 429441    False
# 429442    False
# 429443    False
# 429444    False
# 429445    False
# 429446    False
# 429447    False
# 429448    False
# 429449    False
# 429450    False
# 429451    False
# 429452    False
# 429453    False
# 429454    False
# 429455    False
# 429456    False
# 429457    False
# 429458    False
# 429459    False
# ...

# %%
df[df['dong'].isin(dong_list)].price_per_area.mean() #강남구 평당 평균값
# 먼저 강남구에 있는 동을 가지는 row를 뽑아오고
# price_per_area attribute에 접급해서 mean()으로 평균치 해주었다.
# Out:
# 1159.915258074253

# %% [markdown]
# 데이터 통계 분석할 때 위의 과정으로 쓴다.

# %%
[1,2,3] in [1,2,3,4] #iterable한 것이 in 뒤에 올 수 있다.
# Out:
# False

# %%
[1,2,3] in [[1,2,3], 4]
# Out:
# True

# %%
df.dong in dong_list # 에러가 뜬다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-8a8dfcc00424> in <module>()
# ----> 1 df.dong in dong_list # 에러가 뜬다.
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# isin의 경우 함수형 paradigm으로 만들었다.

# %%
list(map(lambda x: x in dong_list, df.dong)) #isin은 이런 방식으로 만들어짐.
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %% [markdown]
# 여러개의 데이터 중에서 특정 filtering에 따른 데이터가 있는지 확인...

# %%
# df[df.isin({'State': ['CA'], 'Metro':['San Francisco']})] #NaN은 값이 없는 것.
df[df.isin({'dong': ['개포동'], 'year':['2009']})]
# column 뽑는것  -> dictionary, attribute, loc, iloc, filter
# row 뽑는것 -> loc, iloc, df['condition'] -> 이렇게 조건에 대해서 True인 것만 보여줌.
# 조건이 있을 때는 행 따라 item을 출력해줌.
# Out:
#         price_per_area  price  con_year    year dong aptnm  month  dat  area  \
# 0                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 1                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 2                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 3                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 4                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 5                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 6                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 7                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 8                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 9                  NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# 10                 NaN    NaN       NaN  2009.0  개포동   NaN    NaN  NaN   NaN
# ...

# %%
type(df['gu'].isin(['강남구','노원구']))
# Out:
# pandas.core.series.Series

# %%
type(df[df['gu'].isin(['강남구','노원구'])])
# Out:
# pandas.core.frame.DataFrame

# %%
df.isin({'gu':['노원구'], 'dong':['월계동']}) 
# 원하는 조건이 2개 이상일 때는 dictionary 형식으로 주고, 리턴되는 객체 형식은 DataFrame으로 리턴 됨
# Out:
#         price_per_area  price  con_year   year   dong  aptnm  month    dat  \
# 0                False  False     False  False  False  False  False  False
# 1                False  False     False  False  False  False  False  False
# 2                False  False     False  False  False  False  False  False
# 3                False  False     False  False  False  False  False  False
# 4                False  False     False  False  False  False  False  False
# 5                False  False     False  False  False  False  False  False
# 6                False  False     False  False  False  False  False  False
# 7                False  False     False  False  False  False  False  False
# 8                False  False     False  False  False  False  False  False
# 9                False  False     False  False  False  False  False  False
# 10               False  False     False  False  False  False  False  False
# ...

# %%
type(df.isin({'gu':['노원구'], 'dong':['월계동']})) 
# dictionary는 Column을 뽑아냄.

# Column 1개이거나 attribute 방식으로 하면 series  ex) data['gu']
# 2개 이상이면 DataFrame ex) data[['gu]]
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[1:3] # DataFrame
df.loc[1:3, "gu"] # series
df.loc[1:3, ["gu"]] # DataFrame
# df[df.loc[1:3, "gu"]] # error뜸
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-8c27a9f9398a> in <module>()
#       2 df.loc[1:3, "gu"] # series
#       3 df.loc[1:3, ["gu"]] # DataFrame
# ----> 4 df[df.loc[1:3, "gu"]] # DataFrame
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %% [markdown]
# 좀전에 condition을 줄 때
# &,|를 써서 할 때는 하나의 column에 대해서만 조건을 줄 때 쓰는 것이고,
# isin 은 여러개의 column에 대해서 조건을 줄때 dictionary 안에 조건을 넣어주어 필터링을 한다.

# %% [markdown]
# 1980 ~ 1995 년까지의 강남구 집값 변화

# %%
df.axes # row와 column 정보를 모두 보여준다.
# Out:
# [RangeIndex(start=0, stop=429466, step=1),
#  Index(['price_per_area', 'price', 'con_year', 'year', 'dong', 'aptnm', 'month',
#         'dat', 'area', 'area_sub', 'loc', 'floor', 'qrt', 'yyyyqrt', 'yyyym',
#         'gu', 'num_children', 'num_elementary', 'num_middle', 'num_high',
#         'edu_subsidy', 'basic_living', 'hospital', 'num_beds', 'park_area',
#         'salary_councilor', 'obesity', 'total_in', 'total_out', 'inner_in',
#         'inner_out', 'outer_in', 'outer_out', 'city_in', 'city_out',
#         'consm_price_idx', 'food_price_idx', 'prod_price_idx',
#         'rental_house_idx', 'pub_service_idx', 'pri_service_idx',
#         'source_price_idx', 'life_price_idx', 'debt', 'farm_assets',
#         'none_farm_assets', 'assets', 'current_assets', 'current_debt_ratio',
#         'asset_debt_ratio', 'seoul_cons_result', 'national_cons_result',
#         'seoul_cons_ratio', 'bond_one_year', 'bond_three_year',
# ...

# %%
df.axes[0] # Row에 대한 정보
# Out:
# RangeIndex(start=0, stop=429466, step=1)

# %%
df.axes[1] # Column을 보여줌
# Out:
# Index(['price_per_area', 'price', 'con_year', 'year', 'dong', 'aptnm', 'month',
#        'dat', 'area', 'area_sub', 'loc', 'floor', 'qrt', 'yyyyqrt', 'yyyym',
#        'gu', 'num_children', 'num_elementary', 'num_middle', 'num_high',
#        'edu_subsidy', 'basic_living', 'hospital', 'num_beds', 'park_area',
#        'salary_councilor', 'obesity', 'total_in', 'total_out', 'inner_in',
#        'inner_out', 'outer_in', 'outer_out', 'city_in', 'city_out',
#        'consm_price_idx', 'food_price_idx', 'prod_price_idx',
#        'rental_house_idx', 'pub_service_idx', 'pri_service_idx',
#        'source_price_idx', 'life_price_idx', 'debt', 'farm_assets',
#        'none_farm_assets', 'assets', 'current_assets', 'current_debt_ratio',
#        'asset_debt_ratio', 'seoul_cons_result', 'national_cons_result',
#        'seoul_cons_ratio', 'bond_one_year', 'bond_three_year',
#        'bond_five_year', 'bond_ten_year', 'corp_bond_yield_rate', 'call_rate',
# ...

# %%
df.columns # Column을 보여줌.
# Out:
# Index(['price_per_area', 'price', 'con_year', 'year', 'dong', 'aptnm', 'month',
#        'dat', 'area', 'area_sub', 'loc', 'floor', 'qrt', 'yyyyqrt', 'yyyym',
#        'gu', 'num_children', 'num_elementary', 'num_middle', 'num_high',
#        'edu_subsidy', 'basic_living', 'hospital', 'num_beds', 'park_area',
#        'salary_councilor', 'obesity', 'total_in', 'total_out', 'inner_in',
#        'inner_out', 'outer_in', 'outer_out', 'city_in', 'city_out',
#        'consm_price_idx', 'food_price_idx', 'prod_price_idx',
#        'rental_house_idx', 'pub_service_idx', 'pri_service_idx',
#        'source_price_idx', 'life_price_idx', 'debt', 'farm_assets',
#        'none_farm_assets', 'assets', 'current_assets', 'current_debt_ratio',
#        'asset_debt_ratio', 'seoul_cons_result', 'national_cons_result',
#        'seoul_cons_ratio', 'bond_one_year', 'bond_three_year',
#        'bond_five_year', 'bond_ten_year', 'corp_bond_yield_rate', 'call_rate',
# ...

# %% [markdown]
# DataFrame -> Series와 index의 집합으로 되어 있다.

# %%
import pandas as pd
df = pd.read_csv('data-zillow.csv',sep=',')

# %%
df.mean(axis=0) # 전체 row의 column마다의 숫자값에 대한 평균값
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.mean(axis=1) # 하나의 row 내에 숫자값에 대한 평균값
# Out:
# 0        2.261937e+05
# 1        2.141160e+05
# 2        8.004267e+04
# 3        5.019133e+04
# 4        8.387667e+04
# 5        7.848800e+04
# 6        2.088007e+05
# 7        6.761167e+04
# 8        3.037490e+05
# 9        5.919967e+04
# 10       4.048800e+05
# 11       1.106107e+05
# 12       1.975800e+04
# 13       4.641100e+04
# 14       3.797500e+04
# 15       6.928600e+04
# 16       4.378300e+04
# 17       1.996287e+05
# 18       2.287850e+05
# 19       4.154733e+04
# 20       1.314377e+05
# 21       1.991630e+05
# 22       7.821333e+04
# 23       3.796633e+04
# 24       5.743500e+04
# 25       1.437660e+05
# 26       5.531700e+04
# 27       6.409300e+04
# 28       7.101900e+04
# 29       7.697733e+04
#              ...
# 10800    9.508133e+04
# 10801    4.300067e+04
# 10802    1.580057e+05
# 10803    1.068157e+05
# 10804    1.228323e+05
# 10805    6.629900e+04
# 10806    1.105600e+05
# 10807    4.130633e+04
# 10808    3.759180e+05
# 10809    3.538200e+04
# ...

# %%
df['RegionID'].max() # series값이기 때문에 1차원이라서 axis값을 넣어줄 필요가 없다.
# Out:
# 737791

# %%
df.mean(axis='rows') # axis=0
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.mean(axis='columns') # axis =1
# Out:
# 0        2.261937e+05
# 1        2.141160e+05
# 2        8.004267e+04
# 3        5.019133e+04
# 4        8.387667e+04
# 5        7.848800e+04
# 6        2.088007e+05
# 7        6.761167e+04
# 8        3.037490e+05
# 9        5.919967e+04
# 10       4.048800e+05
# 11       1.106107e+05
# 12       1.975800e+04
# 13       4.641100e+04
# 14       3.797500e+04
# 15       6.928600e+04
# 16       4.378300e+04
# 17       1.996287e+05
# 18       2.287850e+05
# 19       4.154733e+04
# 20       1.314377e+05
# 21       1.991630e+05
# 22       7.821333e+04
# 23       3.796633e+04
# 24       5.743500e+04
# 25       1.437660e+05
# 26       5.531700e+04
# 27       6.409300e+04
# 28       7.101900e+04
# 29       7.697733e+04
#              ...
# 10800    9.508133e+04
# 10801    4.300067e+04
# 10802    1.580057e+05
# 10803    1.068157e+05
# 10804    1.228323e+05
# 10805    6.629900e+04
# 10806    1.105600e+05
# 10807    4.130633e+04
# 10808    3.759180e+05
# 10809    3.538200e+04
# ...

# %%
df.filter(regex='Region', axis=1) 
# 열에서 Region이라는 String을 가지는 것을 filtering해줌.
# Out:
#        RegionID         RegionName
# 0          6181           New York
# 1         12447        Los Angeles
# 2         17426            Chicago
# 3         13271       Philadelphia
# 4         40326            Phoenix
# 5         18959          Las Vegas
# 6         54296          San Diego
# 7         38128             Dallas
# 8         33839           San Jose
# 9         25290       Jacksonville
# 10        20330      San Francisco
# 11        10221             Austin
# 12        17762            Detroit
# 13        10920           Columbus
# 14        32811            Memphis
# 15        24043          Charlotte
# 16        17933            El Paso
# 17        44269             Boston
# 18        16037            Seattle
# 19         3523          Baltimore
# 20        11093             Denver
# 21        41568         Washington
# 22         6118          Nashville
# 23         5976          Milwaukee
# 24         7481             Tucson
# 25        13373           Portland
# ...

# %%
df.filter(regex='([0-9]{3})', axis=0)
# row중에 3자리 숫자를 라벨로 가지는 row들을 필터링해줌.
# Out:
#              Date  RegionID         RegionName State  \
# 100    2017-05-31     54346         Scottsdale    AZ
# 101    2017-05-31     41760      Winston-Salem    NC
# 102    2017-05-31     52650             Irvine    CA
# 103    2017-05-31      6752           Richmond    VA
# 104    2017-05-31     10477         Boca Raton    FL
# 105    2017-05-31     13150             Oxnard    CA
# 106    2017-05-31     44282          Bradenton    FL
# 107    2017-05-31     26967         Santa Rosa    CA
# 108    2017-05-31     17759         Des Moines    IA
# 109    2017-05-31     13478               Reno    NV
# 110    2017-05-31     20604            Spokane    WA
# 111    2017-05-31     10210            Augusta    GA
# 112    2017-05-31     27362             Tacoma    WA
# 113    2017-05-31     11671       Grand Rapids    MI
# 114    2017-05-31      6285          Oceanside    CA
# 115    2017-05-31     24821        Gainesville    FL
# 116    2017-05-31     14701         Woodbridge    VA
# ...

# %%
import pandas as pd
df = pd.read_csv('data-netflix.csv',index_col='title')

# %%
df.filter(regex='Anato') # axis = 0이 default로 나오기 때문에 index에서 'Anoto'를 가지는 column 데이터들을 뽑아낸 것임.
# index가 문자열일 경우 이렇게 정규식을 꼭 써서 해야 된다.
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
import pandas as pd
df = pd.read_csv('data-zillow.csv')

# %%
df.info() # object는 거의 대부분 문자열일 것이다.
#문자열의 경우 regex로 해결함.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
df.RegionName.str.capitalize() #첫번째 문자에 대해서 대문자화 해줌
#info했을 때 object의 경우 시간.장소.string.
#object의 경우 .str의 help function을 지원해준다.
# Out:
# 0                 New york
# 1              Los angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las vegas
# 6                San diego
# 7                   Dallas
# 8                 San jose
# 9             Jacksonville
# 10           San francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma city
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount sidney
# 10801          Cedar grove
# 10802                Clark
# ...

# %%
df.RegionName.str.upper() #문자에 대해서 대문자화 해줌
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
df['RegionName'].str.upper() 
#이렇게 dictionary방식으로 쓸 경우 tab 키를 통해서 메소드를 미리보기 지원을 안해줌(Jupyter notebook에서는...)
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
df['RegionName'] = df.RegionName.str.upper()

# %%
df.RegionName.str.replace('YORK','york!')
# RegionName에서 YORK를 york!로 바꿔줌.
# Out:
# 0                NEW york!
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %% [markdown]
# df.RegionName.str은 보통 string에 대한 함수들을 거의 다 갖고 있다.
# (모든 컬럼에 대해서 적용이 되기 때문에 함수형 기법)

# %%
df.RegionName.map(lambda x:x+'조보아')
# Out:
# 0                 NEW YORK조보아
# 1              LOS ANGELES조보아
# 2                  CHICAGO조보아
# 3             PHILADELPHIA조보아
# 4                  PHOENIX조보아
# 5                LAS VEGAS조보아
# 6                SAN DIEGO조보아
# 7                   DALLAS조보아
# 8                 SAN JOSE조보아
# 9             JACKSONVILLE조보아
# 10           SAN FRANCISCO조보아
# 11                  AUSTIN조보아
# 12                 DETROIT조보아
# 13                COLUMBUS조보아
# 14                 MEMPHIS조보아
# 15               CHARLOTTE조보아
# 16                 EL PASO조보아
# 17                  BOSTON조보아
# 18                 SEATTLE조보아
# 19               BALTIMORE조보아
# 20                  DENVER조보아
# 21              WASHINGTON조보아
# 22               NASHVILLE조보아
# 23               MILWAUKEE조보아
# 24                  TUCSON조보아
# 25                PORTLAND조보아
# 26           OKLAHOMA CITY조보아
# 27                   OMAHA조보아
# 28             ALBUQUERQUE조보아
# 29                  FRESNO조보아
#                  ...
# ...

# %%
df.RegionName.map(lambda x: x.format('')) #함수형 기법.... 컬럼의 모든 데이터에 대해서 다 바꿔줌.
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
df.County.str.lower()
# Out:
# 0                      queens
# 1                 los angeles
# 2                        cook
# 3                philadelphia
# 4                    maricopa
# 5                       clark
# 6                   san diego
# 7                      dallas
# 8                 santa clara
# 9                       duval
# 10              san francisco
# 11                     travis
# 12                      wayne
# 13                   franklin
# 14                     shelby
# 15                mecklenburg
# 16                    el paso
# 17                    suffolk
# 18                       king
# 19             baltimore city
# 20                     denver
# 21       district of columbia
# 22                   davidson
# 23                  milwaukee
# 24                       pima
# 25                  multnomah
# 26                   oklahoma
# 27                    douglas
# 28                 bernalillo
# 29                     fresno
#                  ...
# ...

# %%
df['조보아'] = df.County.str.len() # 문근영이라는 column에 ,County의 개수를 넣는다.

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           NEW YORK    NY
# 1      2017-05-31     12447        LOS ANGELES    CA
# 2      2017-05-31     17426            CHICAGO    IL
# 3      2017-05-31     13271       PHILADELPHIA    PA
# 4      2017-05-31     40326            PHOENIX    AZ
# 5      2017-05-31     18959          LAS VEGAS    NV
# 6      2017-05-31     54296          SAN DIEGO    CA
# 7      2017-05-31     38128             DALLAS    TX
# 8      2017-05-31     33839           SAN JOSE    CA
# 9      2017-05-31     25290       JACKSONVILLE    FL
# 10     2017-05-31     20330      SAN FRANCISCO    CA
# 11     2017-05-31     10221             AUSTIN    TX
# 12     2017-05-31     17762            DETROIT    MI
# 13     2017-05-31     10920           COLUMBUS    OH
# 14     2017-05-31     32811            MEMPHIS    TN
# 15     2017-05-31     24043          CHARLOTTE    NC
# 16     2017-05-31     17933            EL PASO    TX
# ...

# %%
import pandas as pd
df = pd.read_csv('apt_final.csv')

# %%
df2 = df[["year", "price"]]

# %%
df2
# Out:
#         year     price
# 0       2009   71000.0
# 1       2009   83700.0
# 2       2009  173500.0
# 3       2009   65000.0
# 4       2009  160000.0
# 5       2009   75000.0
# 6       2009   82000.0
# 7       2009   78000.0
# 8       2009  100000.0
# 9       2009   44800.0
# 10      2009   37000.0
# 11      2009   53000.0
# 12      2009  112000.0
# 13      2009   78000.0
# 14      2009   80000.0
# 15      2009  113500.0
# 16      2009   66000.0
# 17      2009   98000.0
# 18      2009  110500.0
# 19      2009  116000.0
# 20      2009   80000.0
# 21      2009   80000.0
# 22      2009   98100.0
# 23      2009   98500.0
# 24      2009   69000.0
# 25      2009   52950.0
# 26      2009  136500.0
# 27      2009   68500.0
# 28      2009   79500.0
# 29      2009   52000.0
# ...      ...       ...
# 429436  2017   31000.0
# 429437  2017   45800.0
# 429438  2017   22800.0
# 429439  2017   34000.0
# 429440  2017   39500.0
# 429441  2017   29000.0
# 429442  2017   29000.0
# 429443  2017   38000.0
# ...

# %%
% matplotlib inline

# %%
df2.groupby('year').mean() #아파트 가격의 년도별 평균을 나타냄
# Out:
#              price
# year
# 2009  53154.423087
# 2010  54481.975525
# 2011  47782.875191
# 2012  49748.876154
# 2013  47549.218954
# 2014  46254.399498
# 2015  47321.686795
# 2016  56794.748497
# 2017  65054.597161

# %%
df2.plot.bar()
